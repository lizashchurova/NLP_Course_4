# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import gzip
import json
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
stopwords = stopwords.words('english')
import re
import spacy
from string import punctuation
import numpy as np
from tqdm import tqdm
from sklearn.feature_extraction.text import TfidfVectorizer
import gensim.downloader
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
nlp = spacy.load('en_core_web_sm', disable=['parser', 'ner'])
punctuation = punctuation + '—–«»·№˚¼°-;&'

# %%
def parse(path):
  g = gzip.open(path, 'rb')
  for l in g:
    yield json.loads(l)

def getDF(path):
  i = 0
  df = {}
  for d in parse(path):
    df[i] = d
    i += 1
  return pd.DataFrame.from_dict(df, orient='index')

# %%
parse('Luxury_Beauty.json.gz')
# Out:
# <generator object parse at 0x7f0bfc1c1190>

# %%
reviews = getDF('/content/drive/MyDrive/Luxury_Beauty.json.gz')

# %%
good_reviews = reviews[['reviewText', 'summary', 'asin']]

# %%
parse('meta_Luxury_Beauty.json.gz')
# Out:
# <generator object parse at 0x7f0ba0aff0b0>

# %%
meta = getDF('/content/drive/MyDrive/meta_Luxury_Beauty.json.gz')

# %%
good_meta = meta[['description', 'title', 'asin']]

# %%
all_data = pd.DataFrame()
all_data = pd.merge(good_reviews, good_meta, on='asin')
all_data['reviewText'] = all_data['reviewText'].fillna(np.nan)
all_data['summary'] = all_data['summary'].fillna(np.nan)
all_data['description'] = all_data['description'].fillna(np.nan)
all_data['title'] = all_data['title'].fillna(np.nan)
all_data['reviewText'] = all_data['reviewText'].dropna()
all_data['summary'] = all_data['summary'].dropna()
all_data['description'] = all_data['description'].dropna()
all_data['title'] = all_data['title'].dropna()
all_data = all_data[~all_data['description'].isna()]
all_data = all_data[~all_data['summary'].isna()]
all_data = all_data[~all_data['reviewText'].isna()]
all_data = all_data[~all_data['title'].isna()]

# %%
desc = []
for description in all_data['description']:
    descriptions = ' '.join(description)
    desc.append(descriptions)
all_data['description'] = desc

# %%
def preprocessing(data, *columns):
  for column in columns:
    print(column)
    all_obj = []
    for obj in tqdm(data[column]):
      lemmatized_obj = ' '.join([token.lemma_ for token in nlp(obj)])
      lemmatized_obj = lemmatized_obj.lower()
      for i in punctuation:
        lemmatized_obj = lemmatized_obj.replace(i, ' ')
        lemmatized_obj = lemmatized_obj.replace('  ', ' ')
      all_obj.append(lemmatized_obj)
    data[column] = all_obj
  return data

# %%
data_preprocessed = preprocessing(all_data.groupby('asin').first().reset_index(), 'description', 'summary', 'reviewText', 'title')
# Out:
# description
# 100%|██████████| 12111/12111 [02:44<00:00, 73.57it/s]
# summary
# 100%|██████████| 12111/12111 [00:37<00:00, 321.59it/s]
# reviewText
# 100%|██████████| 12111/12111 [01:18<00:00, 154.08it/s]
# title
# 100%|██████████| 12111/12111 [00:41<00:00, 288.43it/s]

# %%
data_preprocessed
# Out:
#              asin                                         reviewText  \
# 0      B00004U9V2  i buy two of these 8 5 fl oz hand cream and ne...
# 1      B0000531EN  i have only use it once so far so not sure how...
# 2      B0000532JH  they add ingredient so it be not 100 pure mud ...
# 3      B00005A77F  this have get to be the very good soap for gar...
# 4      B00005NDTD                                  love this lotion
# ...           ...                                                ...
# 12106  B01HIQEOLO                     color be perfect go on smooth
# 12107  B01HIQHQU0  not impressed with this very dull gray blue co...
# 12108  B01HIQIEYC  i receive lot of compliment when i wear this c...
# 12109  B01HJ2UY0W  the perfume be good but the spray head break off
# 12110  B01HJ2UY1G                                   great fragrance
#
#                                    summary  \
# 0                    dispenser do not work
# 1                               over price
# 2                    product have get bad
# 3                            good soap go
# 4                                four star
# ...                                    ...
# 12106                            five star
# 12107                                 blah
# 12108                      fantastic color
# 12109  spray head break off within a month
# 12110                            five star
#
#                                              description  \
# 0      after a long day of handle thorny situation ou...
# 1      if you have not experience the pleasure of bat...
# 2      rich black mineral mud harvest from the bank o...
# 3      this liquid soap with convenient pump dispense...
# 4      remember why you love your favorite blanket th...
# ...                                                  ...
# 12106  cnd shellac be design to be use as a system fe...
# 12107  cnd shellac be design to be use as a system fe...
# 12108   cnd craft culture collection patina buckle di...
# 12109  the i be juicy couture girl be once again take...
# 12110  i love juicy couture eau de parfum spray 3 4 o...
#
#                                                    title
# 0      crabtree amp evelyn gardener s ultra moisturis...
# 1                                       ahava bath salts
# 2            ahava dead sea mineral mud 8 5 oz pack of 4
# 3      crabtree amp evelyn hand soap gardeners 10 1 f...
# 4                                     soy milk hand crme
# ...                                                  ...
# 12106                        cnd shellac leather satchel
# 12107               cnd shellac power polish denim patch
# 12108             cnd shellac power polish patina buckle
# 12109  juicy couture i love juicy couture 1 7 fl oz p...
# 12110  juicy couture i love juicy couture 3 4 fl oz p...
#
# [12111 rows x 5 columns]

# %% [markdown]
# **Способы для поиска упоминания товаров в отзывах**
#
# 1.   Использовать шаблоны, которые задают грамматические и синтаксические правила, осовывающиеся на частях речи;
# 2.   Поиск по n-граммам через формирование шаблонов, содержащих категории. Но категории часто оказываются пустыми -> работать с ними не стоит. Можно посмотреть на сами категории, то есть что из себя представляют, какрй ассортимент охватывают и тд;
# 3. Создать словари с ключевыми словами из пересечения description и title. Если ключевое слово description есть в title - включаем его в словарь. Словарь можно дополнить путем использования эмбеддингов: ищем похожие слова и добавляем в словарь. Тут могут возникнуть проблемы с ключевыми словами и частотностью отдельных слов в целом.

# %% [markdown]
# **Создаем словарь с ключевыми словами**

# %%
 vectorizer = TfidfVectorizer()

# %% [markdown]
# Попробуем использовать Tf-Idf, так как в первой домашней работе он лучше всего справился с выделением ключевых слов.

# %%
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
def tfidf_keywords(text):
  if len(text) <= 1:
    return 'NO KEYWORDS'
  else:
    X = vectorizer.fit_transform(text)
    feature_names = np.array(vectorizer.get_feature_names())
    denselist = np.array(X.todense())
    indices = denselist.argsort()[0]
    text_keywords = list(feature_names[indices[::-1][:20]])
    return text_keywords

# %%
tfidf_keywords_list = []
for text in tqdm(data_preprocessed['reviewText']):
  tfidf_keywords_list.append(tfidf_keywords(text.split()))
# Out:
# 100%|██████████| 12111/12111 [00:18<00:00, 670.61it/s]

# %%
df_analysis = pd.DataFrame()
df_analysis['title'] = data_preprocessed['title']
df_analysis['keywords'] = tfidf_keywords_list
df_analysis = df_analysis.loc[df_analysis['keywords'] != 'NO KEYWORDS'].reset_index()
df_analysis = df_analysis.drop(columns='index')
df_analysis
# Out:
#                                                    title  \
# 0      crabtree amp evelyn gardener s ultra moisturis...
# 1                                       ahava bath salts
# 2            ahava dead sea mineral mud 8 5 oz pack of 4
# 3      crabtree amp evelyn hand soap gardeners 10 1 f...
# 4                                     soy milk hand crme
# ...                                                  ...
# 11823                        cnd shellac leather satchel
# 11824               cnd shellac power polish denim patch
# 11825             cnd shellac power polish patina buckle
# 11826  juicy couture i love juicy couture 1 7 fl oz p...
# 11827  juicy couture i love juicy couture 3 4 fl oz p...
#
#                                                 keywords
# 0      [work, do, neither, much, it, hand, get, fl, d...
# 1      [will, could, here, have, great, good, give, f...
# 2      [they, weird, not, add, and, anymore, be, have...
# 3      [this, wrong, for, in, house, hope, have, hand...
# 4                                   [love, this, lotion]
# ...                                                  ...
# 11823               [color, smooth, perfect, on, go, be]
# 11824  [not, with, impressed, blue, but, cnd, color, ...
# 11825  [your, you, and, angle, at, color, compliment,...
# 11826  [the, spray, perfume, off, head, good, but, br...
# 11827                                 [great, fragrance]
#
# [11828 rows x 2 columns]

# %%
kw_freq = {}
for i in range(len(df_analysis)):
  for kw in df_analysis['keywords'][i]:
    if kw in df_analysis['title'][i].split():
      if kw in kw_freq.keys():
        kw_freq[kw] += 1
      else:
        kw_freq[kw] = 1

# %%
sorted_kw = sorted(kw_freq.items(), key=lambda kv: kv[1], reverse=True)
sorted_kw
# Out:
# [('hair', 446),
#  ('for', 362),
#  ('cream', 231),
#  ('and', 226),
#  ('eye', 161),
#  ('brush', 161),
#  ('lip', 132),
#  ('shampoo', 127),
#  ('color', 122),
#  ('conditioner', 115),
#  ('hand', 109),
#  ('nail', 101),
#  ('gel', 101),
#  ('skin', 93),
#  ('body', 92),
#  ('lotion', 84),
#  ('face', 83),
#  ('in', 72),
#  ('iron', 68),
#  ('the', 68),
#  ('cleanser', 64),
#  ('be', 59),
#  ('dry', 58),
#  ('polish', 54),
#  ('dryer', 54),
#  ('foundation', 50),
#  ('candle', 50),
#  ('curl', 49),
#  ('mask', 49),
#  ('oil', 48),
#  ('soap', 47),
#  ('with', 47),
#  ('mascara', 39),
#  ('spray', 39),
#  ('of', 37),
#  ('concealer', 35),
#  ('blush', 34),
#  ('gloss', 34),
#  ('moisturizer', 32),
#  ('lipstick', 31),
#  ('balm', 30),
#  ('jane', 28),
#  ('iredale', 28),
#  ('hold', 28),
#  ('zoya', 28),
#  ('lavender', 28),
#  ('occitane', 27),
#  ('eyeliner', 27),
#  ('elemis', 26),
#  ('oz', 26),
#  ('lash', 25),
#  ('kit', 25),
#  ('evelyn', 24),
#  ('facial', 24),
#  ('butter', 24),
#  ('crabtree', 23),
#  ('makeup', 23),
#  ('powder', 23),
#  ('bath', 23),
#  ('black', 23),
#  ('serum', 23),
#  ('borghese', 22),
#  ('wash', 22),
#  ('jack', 22),
#  ('day', 22),
#  ('bliss', 20),
#  ('hot', 20),
#  ('de', 20),
#  ('to', 20),
#  ('gift', 19),
#  ('it', 19),
#  ('scrub', 18),
#  ('pencil', 18),
#  ('shave', 18),
#  ('ahava', 17),
#  ('baby', 17),
#  ('coat', 16),
#  ('brow', 16),
#  ('shaving', 16),
#  ('chi', 15),
#  ('bottle', 15),
#  ('deodorant', 15),
#  ('foot', 15),
#  ('mario', 15),
#  ('shower', 15),
#  ('shine', 15),
#  ('night', 14),
#  ('glytone', 14),
#  ('japonesque', 14),
#  ('glo', 14),
#  ('hairspray', 14),
#  ('london', 14),
#  ('flat', 14),
#  ('julep', 14),
#  ('elizabeth', 13),
#  ('free', 13),
#  ('cuticle', 13),
#  ('love', 13),
#  ('lorac', 13),
#  ('juice', 13),
#  ('eau', 13),
#  ('fl', 12),
#  ('base', 12),
#  ('guinot', 12),
#  ('diffuser', 12),
#  ('remover', 12),
#  ('gentle', 12),
#  ('travel', 12),
#  ('tan', 12),
#  ('liner', 12),
#  ('image', 12),
#  ('burberry', 12),
#  ('opi', 11),
#  ('stila', 11),
#  ('la', 11),
#  ('sample', 11),
#  ('leave', 10),
#  ('moisture', 10),
#  ('curler', 10),
#  ('mist', 10),
#  ('daily', 10),
#  ('scalp', 10),
#  ('primer', 10),
#  ('cnd', 10),
#  ('biolage', 10),
#  ('light', 9),
#  ('fine', 9),
#  ('arden', 9),
#  ('sensitive', 9),
#  ('cologne', 9),
#  ('after', 9),
#  ('long', 9),
#  ('perfume', 9),
#  ('honey', 9),
#  ('sunscreen', 9),
#  ('rusk', 9),
#  ('beauty', 9),
#  ('dark', 9),
#  ('geller', 9),
#  ('do', 9),
#  ('beard', 9),
#  ('one', 8),
#  ('not', 8),
#  ('shadow', 8),
#  ('eyebrow', 8),
#  ('rich', 8),
#  ('foam', 8),
#  ('volume', 8),
#  ('duo', 8),
#  ('cleansing', 8),
#  ('eternity', 8),
#  ('brown', 8),
#  ('spf', 8),
#  ('home', 8),
#  ('self', 8),
#  ('laura', 8),
#  ('peel', 8),
#  ('bag', 8),
#  ('anthony', 7),
#  ('essie', 7),
#  ('jan', 7),
#  ('mousse', 7),
#  ('glow', 7),
#  ('highlighter', 7),
#  ('mitchell', 7),
#  ('flower', 7),
#  ('red', 7),
#  ('parfum', 7),
#  ('fragrance', 7),
#  ('line', 7),
#  ('cellex', 7),
#  ('by', 7),
#  ('frizz', 7),
#  ('rose', 7),
#  ('mineral', 7),
#  ('toner', 7),
#  ('boo', 7),
#  ('badescu', 7),
#  ('man', 7),
#  ('bar', 7),
#  ('jurlique', 7),
#  ('calvin', 7),
#  ('case', 7),
#  ('comb', 7),
#  ('pureology', 7),
#  ('heat', 7),
#  ('floris', 7),
#  ('make', 7),
#  ('eyeshadow', 7),
#  ('go', 7),
#  ('set', 7),
#  ('glass', 7),
#  ('mud', 6),
#  ('get', 6),
#  ('dermablend', 6),
#  ('cargo', 6),
#  ('men', 6),
#  ('archipelago', 6),
#  ('sun', 6),
#  ('smooth', 6),
#  ('korres', 6),
#  ('lemon', 6),
#  ('foaming', 6),
#  ('pomade', 6),
#  ('lift', 6),
#  ('hydrating', 6),
#  ('oily', 6),
#  ('epicuren', 6),
#  ('acne', 6),
#  ('furterer', 6),
#  ('clinical', 6),
#  ('clear', 6),
#  ('bioelement', 6),
#  ('moisturizing', 6),
#  ('bronzer', 6),
#  ('neck', 6),
#  ('clean', 6),
#  ('bristle', 6),
#  ('wrinkle', 6),
#  ('at', 6),
#  ('all', 6),
#  ('amouage', 6),
#  ('osmosis', 6),
#  ('mirror', 6),
#  ('lafco', 6),
#  ('ritual', 6),
#  ('menscience', 5),
#  ('extra', 5),
#  ('green', 5),
#  ('art', 5),
#  ('finish', 5),
#  ('treatment', 5),
#  ('coverage', 5),
#  ('compact', 5),
#  ('curling', 5),
#  ('ionic', 5),
#  ('glaze', 5),
#  ('noodle', 5),
#  ('creme', 5),
#  ('clarisonic', 5),
#  ('iceland', 5),
#  ('pevonia', 5),
#  ('matte', 5),
#  ('nuxe', 5),
#  ('my', 5),
#  ('razor', 5),
#  ('jessica', 5),
#  ('obagi', 5),
#  ('liquid', 5),
#  ('palette', 5),
#  ('box', 5),
#  ('exfoliate', 5),
#  ('mason', 5),
#  ('ddf', 5),
#  ('klorane', 5),
#  ('boost', 5),
#  ('crayon', 5),
#  ('have', 5),
#  ('fhi', 5),
#  ('root', 5),
#  ('dr', 5),
#  ('keratin', 5),
#  ('english', 5),
#  ('laundry', 5),
#  ('brit', 5),
#  ('this', 5),
#  ('cover', 4),
#  ('glycolic', 4),
#  ('fiber', 4),
#  ('longo', 4),
#  ('marvis', 4),
#  ('jasmine', 4),
#  ('mint', 4),
#  ('detangler', 4),
#  ('goetz', 4),
#  ('paul', 4),
#  ('perfect', 4),
#  ('deep', 4),
#  ('jean', 4),
#  ('june', 4),
#  ('jacobs', 4),
#  ('kneipp', 4),
#  ('john', 4),
#  ('on', 4),
#  ('gehwol', 4),
#  ('blinc', 4),
#  ('bio', 4),
#  ('leonor', 4),
#  ('greyl', 4),
#  ('system', 4),
#  ('baxter', 4),
#  ('file', 4),
#  ('bubble', 4),
#  ('eyelash', 4),
#  ('bioelements', 4),
#  ('finishing', 4),
#  ('complex', 4),
#  ('blemish', 4),
#  ('klein', 4),
#  ('zirh', 4),
#  ('immortelle', 4),
#  ('masque', 4),
#  ('hour', 4),
#  ('oribe', 4),
#  ('hampton', 4),
#  ('clipper', 4),
#  ('heel', 4),
#  ('musgo', 4),
#  ('mustela', 4),
#  ('vichy', 4),
#  ('full', 4),
#  ('amika', 4),
#  ('shellac', 4),
#  ('give', 4),
#  ('nioxin', 4),
#  ('nuface', 4),
#  ('emi', 4),
#  ('jay', 4),
#  ('xtreme', 4),
#  ('stay', 4),
#  ('erno', 4),
#  ('lacoste', 4),
#  ('boar', 4),
#  ('loma', 4),
#  ('elchim', 4),
#  ('texture', 4),
#  ('eyeko', 4),
#  ('t3', 4),
#  ('head', 4),
#  ('johnson', 4),
#  ('foreo', 4),
#  ('cult', 4),
#  ('panda', 4),
#  ('ck', 3),
#  ('dermadoctor', 3),
#  ('kp', 3),
#  ('pca', 3),
#  ('neova', 3),
#  ('growth', 3),
#  ('logistics', 3),
#  ('elite', 3),
#  ('blonde', 3),
#  ('shaper', 3),
#  ('marini', 3),
#  ('pre', 3),
#  ('philip', 3),
#  ('citrus', 3),
#  ('tree', 3),
#  ('tea', 3),
#  ('brightening', 3),
#  ('redness', 3),
#  ('hydra', 3),
#  ('no', 3),
#  ('sugar', 3),
#  ('sharpener', 3),
#  ('vitamin', 3),
#  ('very', 3),
#  ('dead', 3),
#  ('ingrown', 3),
#  ('thebalm', 3),
#  ('formula', 3),
#  ('couture', 3),
#  ('anti', 3),
#  ('firming', 3),
#  ('mini', 3),
#  ('wear', 3),
#  ('happ', 3),
#  ('blend', 3),
#  ('eshave', 3),
#  ('styling', 3),
#  ('aloe', 3),
#  ('spot', 3),
#  ('fluid', 3),
#  ('use', 3),
#  ('fango', 3),
#  ('luxury', 3),
#  ('contour', 3),
#  ('healing', 3),
#  ('fan', 3),
#  ('tweezer', 3),
#  ('moroccanoil', 3),
#  ('gold', 3),
#  ('milk', 3),
#  ('choo', 3),
#  ('lily', 3),
#  ('jouer', 3),
#  ('hard', 3),
#  ('toothbrush', 3),
#  ('neuma', 3),
#  ('hydrate', 3),
#  ('even', 3),
#  ('indie', 3),
#  ('grooming', 3),
#  ('colorproof', 3),
#  ('filter', 3),
#  ('up', 3),
#  ('good', 3),
#  ('flawless', 3),
#  ('forever', 3),
#  ('firm', 3),
#  ('frasca', 3),
#  ('liberata', 3),
#  ('beach', 3),
#  ('georgie', 3),
#  ('joy', 3),
#  ('natural', 3),
#  ('wen', 3),
#  ('tie', 3),
#  ('juicy', 3),
#  ('sabon', 3),
#  ('strivectin', 3),
#  ('sponge', 3),
#  ('kenneth', 3),
#  ('onesta', 3),
#  ('curly', 3),
#  ('lauren', 3),
#  ('em', 3),
#  ('electric', 3),
#  ('kora', 3),
#  ('lvx', 3),
#  ('care', 3),
#  ('collection', 2),
#  ('diamond', 2),
#  ('hydrator', 2),
#  ('vincent', 2),
#  ('water', 2),
#  ('avenue', 2),
#  ('sparkle', 2),
#  ('havana', 2),
#  ('thick', 2),
#  ('jasmin', 2),
#  ('loss', 2),
#  ('salt', 2),
#  ('morning', 2),
#  ('freeze', 2),
#  ('enhancer', 2),
#  ('scent', 2),
#  ('obsession', 2),
#  ('caron', 2),
#  ('homme', 2),
#  ('patou', 2),
#  ('your', 2),
#  ('creamy', 2),
#  ('bowl', 2),
#  ('plus', 2),
#  ('crease', 2),
#  ('muscle', 2),
#  ('jar', 2),
#  ('purple', 2),
#  ('dandruff', 2),
#  ('floss', 2),
#  ('eraser', 2),
#  ('control', 2),
#  ('rene', 2),
#  ('astringent', 2),
#  ('ocean', 2),
#  ('mizani', 2),
#  ('combination', 2),
#  ('concentrate', 2),
#  ('fx', 2),
#  ('oscar', 2),
#  ('blandi', 2),
#  ('somme', 2),
#  ('institute', 2),
#  ('intense', 2),
#  ('illuminating', 2),
#  ('apricot', 2),
#  ('chamomile', 2),
#  ('bioderma', 2),
#  ('orange', 2),
#  ('white', 2),
#  ('clay', 2),
#  ('molding', 2),
#  ('gum', 2),
#  ('leg', 2),
#  ('drench', 2),
#  ('sebastian', 2),
#  ('cassis', 2),
#  ('normal', 2),
#  ('essential', 2),
#  ('under', 2),
#  ('moisturize', 2),
#  ('shimmer', 2),
#  ('benzoyl', 2),
#  ('salon', 2),
#  ('calming', 2),
#  ('esthederm', 2),
#  ('humidity', 2),
#  ('xen', 2),
#  ('berry', 2),
#  ('mild', 2),
#  ('bosley', 2),
#  ('perricone', 2),
#  ('blow', 2),
#  ('intensive', 2),
#  ('expert', 2),
#  ('exfoliator', 2),
#  ('pmd', 2),
#  ('express', 2),
#  ('callus', 2),
#  ('juliette', 2),
#  ('conditioning', 2),
#  ('kaplan', 2),
#  ('16', 2),
#  ('temptu', 2),
#  ('mix', 2),
#  ('arrojo', 2),
#  ('ghd', 2),
#  ('deepshine', 2),
#  ('jimmy', 2),
#  ('nia', 2),
#  ('edge', 2),
#  ('hairmax', 2),
#  ('malibu', 2),
#  ('massage', 2),
#  ('fresh', 2),
#  ('over', 2),
#  ('touch', 2),
#  ('source', 2),
#  ('framesi', 2),
#  ('strong', 2),
#  ('correct', 2),
#  ('farmacista', 2),
#  ('device', 2),
#  ('newborn', 2),
#  ('gianna', 2),
#  ('lovely', 2),
#  ('silver', 2),
#  ('30', 2),
#  ('refill', 2),
#  ('magic', 2),
#  ('laszlo', 2),
#  ('fatigue', 2),
#  ('pad', 2),
#  ('tin', 2),
#  ('real', 2),
#  ('stacey', 2),
#  ('vita', 2),
#  ('sachet', 2),
#  ('orlane', 2),
#  ('knight', 2),
#  ('opus', 2),
#  ('eucalyptus', 2),
#  ('little', 2),
#  ('bee', 2),
#  ('rodial', 2),
#  ('medium', 2),
#  ('room', 2),
#  ('difference', 2),
#  ('edition', 2),
#  ('inch', 2),
#  ('skincare', 2),
#  ('illuminate', 2),
#  ('back', 2),
#  ('laser', 2),
#  ('lacquer', 2),
#  ('essence', 2),
#  ('grande', 2),
#  ('koh', 2),
#  ('gen', 2),
#  ('brandt', 2),
#  ('minute', 2),
#  ('luna', 2),
#  ('liftactiv', 2),
#  ('davine', 2),
#  ('porefection', 2),
#  ('professional', 2),
#  ('mark', 2),
#  ('woman', 2),
#  ('sheet', 2),
#  ('flash', 2),
#  ('hydrasource', 2),
#  ('dual', 2),
#  ('top', 2),
#  ('nude', 2),
#  ('rouge', 2),
#  ('bunny', 2),
#  ('trio', 2),
#  ('bolin', 2),
#  ('life', 2),
#  ('pore', 2),
#  ('paste', 2),
#  ('actives', 2),
#  ('cole', 2),
#  ('babor', 2),
#  ('purse', 2),
#  ('california', 2),
#  ('micro', 2),
#  ('xfusion', 2),
#  ('philosophy', 2),
#  ('crush', 2),
#  ('ego', 2),
#  ('reuzel', 2),
#  ('wand', 2),
#  ('smith', 2),
#  ('crepe', 2),
#  ('calista', 2),
#  ('barrel', 2),
#  ('davines', 2),
#  ('credit', 2),
#  ('cura', 1),
#  ('wet', 1),
#  ('ouidad', 1),
#  ('revivogen', 1),
#  ('glycolix', 1),
#  ('handy', 1),
#  ('savannah', 1),
#  ('angel', 1),
#  ('haley', 1),
#  ('cork', 1),
#  ('eczema', 1),
#  ('bioglycolic', 1),
#  ('lolita', 1),
#  ('fifth', 1),
#  ('hydroplane', 1),
#  ('crop', 1),
#  ('whitening', 1),
#  ('bonnet', 1),
#  ('solano', 1),
#  ('tocade', 1),
#  ('hugo', 1),
#  ('cellutox', 1),
#  ('loose', 1),
#  ('lanza', 1),
#  ('anza', 1),
#  ('nutrizone', 1),
#  ('zero', 1),
#  ('weight', 1),
#  ('propolis', 1),
#  ('marcel', 1),
#  ('tools', 1),
#  ('puffiness', 1),
#  ('high', 1),
#  ('poetic', 1),
#  ('posay', 1),
#  ('dropper', 1),
#  ('apron', 1),
#  ('isola', 1),
#  ('bella', 1),
#  ('women', 1),
#  ('aquolina', 1),
#  ('ounce', 1),
#  ('pink', 1),
#  ('roll', 1),
#  ('shimmering', 1),
#  ('70', 1),
#  ('large', 1),
#  ('wild', 1),
#  ('nourishing', 1),
#  ('fns', 1),
#  ('grapefruit', 1),
#  ('honeysuckle', 1),
#  ('multi', 1),
#  ('azzaro', 1),
#  ('healthy', 1),
#  ('enhancing', 1),
#  ('fleurs', 1),
#  ('rocaille', 1),
#  ('peptide', 1),
#  ('tre', 1),
#  ('jealousy', 1),
#  ('eyed', 1),
#  ('starry', 1),
#  ('equalizer', 1),
#  ('bulgarian', 1),
#  ('volumizer', 1),
#  ('jele', 1),
#  ('thickr', 1),
#  ('delicate', 1),
#  ('di', 1),
#  ('anastasia', 1),
#  ('flushed', 1),
#  ('work', 1),
#  ('emollient', 1),
#  ('ultra', 1),
#  ('flake', 1),
#  ('cosmeceuticals', 1),
#  ('copper', 1),
#  ('puff', 1),
#  ('bump', 1),
#  ('hands', 1),
#  ('acid', 1),
#  ('salicylic', 1),
#  ('nectifirm', 1),
#  ('jet', 1),
#  ('pour', 1),
#  ('dubai', 1),
#  ('alora', 1),
#  ('lipidro', 1),
#  ('cheek', 1),
#  ('elimin8', 1),
#  ('holder', 1),
#  ('phyto', 1),
#  ('ginger', 1),
#  ('gardenia', 1),
#  ('cucumber', 1),
#  ('rs2', 1),
#  ('proraso', 1),
#  ('house', 1),
#  ('stickey', 1),
#  ('chip', 1),
#  ('mattifying', 1),
#  ('privet', 1),
#  ('restoration', 1),
#  ('lifter', 1),
#  ('kitten', 1),
#  ('backcomb', 1),
#  ('libre', 1),
#  ('fungus', 1),
#  ('mexoryl', 1),
#  ('flipper', 1),
#  ('fig', 1),
#  ('malin', 1),
#  ('beat', 1),
#  ('patch', 1),
#  ('crystal', 1),
#  ('histoires', 1),
#  ('parfums', 1),
#  ('1740', 1),
#  ('intervention', 1),
#  ('extrait', 1),
#  ('bisse', 1),
#  ('natura', 1),
#  ('ice', 1),
#  ('toothpaste', 1),
#  ('block', 1),
#  ('brillante', 1),
#  ('densifying', 1),
#  ('square', 1),
#  ('brilliance', 1),
#  ('badger', 1),
#  ('heal', 1),
#  ('antiperspirant', 1),
#  ('frangipani', 1),
#  ('straight', 1),
#  ('dovo', 1),
#  ('clark', 1),
#  ('golden', 1),
#  ('more', 1),
#  ('glowology', 1),
#  ('frizzy', 1),
#  ('cloth', 1),
#  ('spice', 1),
#  ('extremely', 1),
#  ('loup', 1),
#  ('egg', 1),
#  ('classic', 1),
#  ('perfecting', 1),
#  ('exfoliating', 1),
#  ('groomer', 1),
#  ('ergonomic', 1),
#  ('luminizer', 1),
#  ('snowsicle', 1),
#  ('nutter', 1),
#  ('glistening', 1),
#  ('bling', 1),
#  ('naughty', 1),
#  ('intellishade', 1),
#  ('retractable', 1),
#  ('fabulous', 1),
#  ('featherweight', 1),
#  ('product', 1),
#  ('talc', 1),
#  ('non', 1),
#  ('stick', 1),
#  ('step', 1),
#  ('penhaligon', 1),
#  ('pear', 1),
#  ('plumper', 1),
#  ('pacifique', 1),
#  ('eyes', 1),
#  ('divine', 1),
#  ('extreme', 1),
#  ('sealer', 1),
#  ('nubrilliance', 1),
#  ('prevage', 1),
#  ('olive', 1),
#  ('less', 1),
#  ('replacement', 1),
#  ('layrite', 1),
#  ('hydropeptide', 1),
#  ('flavor', 1),
#  ('heart', 1),
#  ('shake', 1),
#  ('skyn', 1),
#  ('surface', 1),
#  ('yu', 1),
#  ('protect', 1),
#  ('just', 1),
#  ('fondant', 1),
#  ('cellulite', 1),
#  ('celebrations', 1),
#  ('leaf', 1),
#  ('dish', 1),
#  ('blood', 1),
#  ('french', 1),
#  ('kiss', 1),
#  ('clutch', 1),
#  ('custom', 1),
#  ('43', 1),
#  ('legend', 1),
#  ('solution', 1),
#  ('aqua', 1),
#  ('supersmile', 1),
#  ('smudge', 1),
#  ('euphoria', 1),
#  ('tutorial', 1),
#  ('valley', 1),
#  ('montblanc', 1),
#  ('botanicals', 1),
#  ('delicato', 1),
#  ('fabulips', 1),
#  ('manicure', 1),
#  ('tela', 1),
#  ('item', 1),
#  ('pack', 1),
#  ('kelp', 1),
#  ('duty', 1),
#  ('power', 1),
#  ('repair', 1),
#  ('sulfate', 1),
#  ('yourself', 1),
#  ('pressed', 1),
#  ('workout', 1),
#  ('creatine', 1),
#  ('revision', 1),
#  ('henckels', 1),
#  ('boscia', 1),
#  ('almond', 1),
#  ('tangle', 1),
#  ('trimmer', 1),
#  ('dragon', 1),
#  ('judith', 1),
#  ('leiber', 1),
#  ('cucurbita', 1),
#  ('rahua', 1),
#  ('from', 1),
#  ('flora', 1),
#  ('lighten', 1),
#  ('chlorine', 1),
#  ('incredi', 1),
#  ('age', 1),
#  ('carly', 1),
#  ('cool', 1),
#  ('barber', 1),
#  ('conceal', 1),
#  ('pigment', 1),
#  ('diego', 1),
#  ('talcum', 1),
#  ('cefiro', 1),
#  ('peony', 1),
#  ('hilite', 1),
#  ('scott', 1),
#  ('exfoliation', 1),
#  ('borba', 1),
#  ('neutralizer', 1),
#  ('bend', 1),
#  ('big', 1),
#  ('so', 1),
#  ('date', 1),
#  ('sage', 1),
#  ('sheer', 1),
#  ('yellow', 1),
#  ('cuppa', 1),
#  ('moss', 1),
#  ('lippy', 1),
#  ('luminize', 1),
#  ('redwood', 1),
#  ('motu', 1),
#  ('pure', 1),
#  ('marula', 1),
#  ('micellar', 1),
#  ('size', 1),
#  ('meg', 1),
#  ('21', 1),
#  ('marly', 1),
#  ('wedge', 1),
#  ('venom', 1),
#  ('reviving', 1),
#  ('shamp', 1),
#  ('digital', 1),
#  ('personalized', 1),
#  ('favorito', 1),
#  ('thickener', 1),
#  ('nectarine', 1),
#  ('tool', 1),
#  ('corrector', 1),
#  ('glossing', 1),
#  ('cake', 1),
#  ('25', 1),
#  ('herbal', 1),
#  ('sorme', 1),
#  ('eltamd', 1),
#  ('pm', 1),
#  ('therapy', 1),
#  ('cocoon', 1),
#  ('bidiffuser', 1),
#  ('wallet', 1),
#  ('viva', 1),
#  ('kumudu', 1),
#  ('working', 1),
#  ('balancing', 1),
#  ('mat', 1),
#  ('filler', 1),
#  ('presence', 1),
#  ('epic', 1),
#  ('payot', 1),
#  ('correcting', 1),
#  ('cradle', 1),
#  ('cap', 1),
#  ('amazing', 1),
#  ('grey', 1),
#  ('fruit', 1),
#  ('soothing', 1),
#  ('see', 1),
#  ('tousled', 1),
#  ('allan', 1),
#  ('signature', 1),
#  ('peeling', 1),
#  ('pedicure', 1),
#  ('awaken', 1),
#  ('jinsoon', 1),
#  ('wax', 1),
#  ('verbena', 1),
#  ('nurse', 1),
#  ('elevate', 1),
#  ('sublime', 1),
#  ('pads', 1),
#  ('silk', 1),
#  ('lady', 1),
#  ('gun', 1),
#  ('recipe', 1),
#  ('elle', 1),
#  ('aime', 1),
#  ('complete', 1),
#  ('cc', 1),
#  ('blowpro', 1),
#  ('china', 1),
#  ('liss', 1),
#  ('lierac', 1),
#  ('wow', 1),
#  ('enzyme', 1),
#  ('stand', 1),
#  ('suma', 1),
#  ('ginseng', 1),
#  ('romantina', 1),
#  ('konjac', 1),
#  ('demi', 1),
#  ('elixir', 1),
#  ('air', 1),
#  ('instain', 1),
#  ('truffle', 1),
#  ('mancera', 1),
#  ('lippmann', 1),
#  ('rgb', 1),
#  ('tint', 1),
#  ('ecru', 1),
#  ('mani', 1),
#  ('splendide', 1),
#  ('malie', 1),
#  ('merveillance', 1),
#  ('lashes', 1),
#  ('mio', 1),
#  ('reduce', 1),
#  ('dura', 1),
#  ('instant', 1),
#  ('molton', 1),
#  ('ciel', 1),
#  ('bb', 1),
#  ('cougar', 1),
#  ('everyday', 1),
#  ('liftlab', 1),
#  ('tahitian', 1),
#  ('soy', 1),
#  ('freezing', 1),
#  ('retinol', 1),
#  ('fragrant', 1),
#  ('wake', 1),
#  ('alfaparf', 1),
#  ('toilette', 1),
#  ('week', 1),
#  ('mitt', 1),
#  ('habdan', 1),
#  ('ila', 1),
#  ('hammam', 1),
#  ('50', 1),
#  ('fatboy', 1),
#  ('hitter', 1),
#  ('heavy', 1),
#  ('hazan', 1),
#  ('starter', 1),
#  ('tooth', 1),
#  ('invincible', 1),
#  ('indulge', 1),
#  ('lee', 1),
#  ('matic', 1),
#  ('pout', 1),
#  ('notting', 1),
#  ('hill', 1),
#  ('62', 1),
#  ...]

# %% [markdown]
# Кажется, что наиболее подходящие слова:
#
# 1. 'cream', 231
# 2. 'brush', 161
# 3. 'shampoo', 127
# 4. 'conditioner', 115
# 5. 'gel', 101
# 6. 'lotion', 84
# 7. 'cleanser', 64
# 8. 'polish', 54
# 9. 'dryer', 54
# 10. 'foundation', 50
# 11. 'candle', 50
# 12. 'mask', 49
# 13. 'oil', 48
# 14. 'soap', 47
# 15. 'mascara', 39
# 16. 'spray', 39
# 17. 'concealer', 35
# 18. 'blush', 34
# 19. 'gloss', 34
# 20. 'moisturizer', 32
# 21. 'lipstick', 31
# 22. 'balm', 30

# %%
lux_list = ['cream', 'brush', 'shampoo', 'conditioner', 'gel', 'lotion', 'cleanser', 
            'polish', 'dryer', 'foundation', 'candle', 'mask', 'oil', 'soap', 
            'mascara', 'spray', 'concealer', 'blush', 'gloss', 'moisturizer', 'lipstick', 'balm']

# %%
ft = gensim.downloader.load('fasttext-wiki-news-subwords-300')
# Out:
# [==================================================] 100.0% 958.5/958.4MB downloaded

# %%
full_lux = []
for lux in lux_list:
  if lux not in full_lux:
    full_lux.append(lux)
    index = 0
    if lux in ft:
      while index != -1:
        simmilar = ft.most_similar(lux)[index][0]
        if lux == preprocessing(simmilar):
          index += 1
        else:
          full_lux.append(simmilar)
          index = -1

# %%
full_lux = set(full_lux)

# %% [markdown]
# **Биграммы**

# %%
bigrams = []

for i, review in enumerate(tqdm(data_preprocessed['reviewText'])):
  review = review.split()
  for lux in full_lux:
    line = []
    for i, word in enumerate(review):
      if word == lux:
        line.append(i)
    if line:
      for i in line:
        if i != 0:
          bigrams.append(review[(i - 1):(i + 1)])
        if i != len(review) - 1:
          bigrams.append(review[i:(i + 2)])
# Out:
# 100%|██████████| 12111/12111 [00:03<00:00, 3689.73it/s]

# %%
bigrams
# Out:
# [['hand', 'cream'],
#  ['cream', 'and'],
#  ['hand', 'cream'],
#  ['cream', 'be'],
#  ['good', 'soap'],
#  ['soap', 'for'],
#  ['evelyn', 'soap'],
#  ['soap', 'for'],
#  ['pump', 'soap'],
#  ['soap', 'could'],
#  ['wrong', 'soap'],
#  ['soap', 'hope'],
#  ['this', 'lotion'],
#  ['different', 'lotion'],
#  ['lotion', 'but'],
#  ['try', 'cream'],
#  ['cream', 'natural'],
#  ['mineral', 'cream'],
#  ['cream', 'yoga'],
#  ['generic', 'moisturizer'],
#  ['moisturizer', 'for'],
#  ['regular', 'moisturizer'],
#  ['moisturizer', 'it'],
#  ['blow', 'dryer'],
#  ['dryer', 'speed'],
#  ['counter', 'cream'],
#  ['cream', 'i'],
#  ['nail', 'polish'],
#  ['polish', 'once'],
#  ['nail', 'polish'],
#  ['polish', 'it'],
#  ['this', 'polish'],
#  ['polish', 'under'],
#  ['this', 'polish'],
#  ['polish', 'i'],
#  ['good', 'polish'],
#  ['polish', 'i'],
#  ['this', 'polish'],
#  ['polish', 'as'],
#  ['glitter', 'polish'],
#  ['polish', 'this'],
#  ['other', 'polish'],
#  ['polish', 'but'],
#  ['the', 'mascara'],
#  ['mascara', 'when'],
#  ['night', 'cream'],
#  ['cream', 'it'],
#  ['from', 'foundation'],
#  ['foundation', 'up'],
#  ['silkcoat', 'balm'],
#  ['balm', 'i'],
#  ['silkcoat', 'balm'],
#  ['balm', 'only'],
#  ['silkcoat', 'balm'],
#  ['balm', 'it'],
#  ['good', 'lotion'],
#  ['lotion', 'ever'],
#  ['of', 'foundation'],
#  ['foundation', 'and'],
#  ['my', 'cleanser'],
#  ['cleanser', 'this'],
#  ['this', 'soap'],
#  ['soap', 'be'],
#  ['too', 'soap'],
#  ['soap', 'disappear'],
#  ['novelty', 'soap'],
#  ['algae', 'cleanser'],
#  ['cleanser', 'first'],
#  ['this', 'shampoo'],
#  ['shampoo', 'work'],
#  ['bad', 'conditioner'],
#  ['conditioner', 'for'],
#  ['terrific', 'shampoo'],
#  ['shampoo', 'you'],
#  ['best', 'shampoo'],
#  ['shampoo', 'and'],
#  ['smell', 'shampoo'],
#  ['shampoo', 'i'],
#  ['this', 'shampoo'],
#  ['of', 'spray'],
#  ['spray', 'would'],
#  ['this', 'cleanser'],
#  ['cleanser', 'in'],
#  ['after', 'spray'],
#  ['spray', 'so'],
#  ['spread', 'foundation'],
#  ['foundation', 'perfectly'],
#  ['this', 'brush'],
#  ['brush', 'year'],
#  ['first', 'brush'],
#  ['brush', 'i'],
#  ['i', 'mascara'],
#  ['mascara', 'even'],
#  ['the', 'brush'],
#  ['brush', 'when'],
#  ['this', 'brush'],
#  ['brush', 'be'],
#  ['these', 'brushes'],
#  ['brushes', 'for'],
#  ['other', 'brushes'],
#  ['brushes', 'this'],
#  ['best', 'brush'],
#  ['brush', 'in'],
#  ['the', 'brush'],
#  ['brush', 'cleans'],
#  ['liquid', 'foundation'],
#  ['foundation', 'it'],
#  ['to', 'foundation'],
#  ['foundation', 'that'],
#  ['and', 'moisturizer'],
#  ['moisturizer', 'so'],
#  ['separate', 'moisturizer'],
#  ['moisturizer', 'and'],
#  ['than', 'lipstick'],
#  ['lipstick', 'i'],
#  ['apply', 'lotion'],
#  ['lotion', 'of'],
#  ['nice', 'blush'],
#  ['blush', 'i'],
#  ['brush', 'brissell'],
#  ['shave', 'cream'],
#  ['cream', 'and'],
#  ['the', 'gel'],
#  ['gel', 'be'],
#  ['s', 'gel'],
#  ['gel', 'the'],
#  ['shave', 'oil'],
#  ['oil', 'the'],
#  ['shave', 'oil'],
#  ['oil', 'anthony'],
#  ['this', 'concealer'],
#  ['concealer', 'for'],
#  ['this', 'lotion'],
#  ['lotion', 'for'],
#  ['other', 'lotion'],
#  ['lotion', 'loose'],
#  ['favorite', 'blush'],
#  ['blush', 'unfortunatley'],
#  ['the', 'blush'],
#  ['blush', 'so'],
#  ['good', 'lotion'],
#  ['lotion', 'for'],
#  ['murad', 'lotion'],
#  ['lotion', 'i'],
#  ['face', 'cream'],
#  ['cream', 'over'],
#  ['in', 'conditioner'],
#  ['conditioner', 'and'],
#  ['this', 'cream'],
#  ['cream', 'for'],
#  ['this', 'blush'],
#  ['blush', 'for'],
#  ['amazing', 'blush'],
#  ['blush', 'for'],
#  ['my', 'brush'],
#  ['brush', 'swipe'],
#  ['hair', 'spray'],
#  ['spray', 'like'],
#  ['regular', 'lotion'],
#  ['lotion', 'when'],
#  ['this', 'moisturizer'],
#  ['moisturizer', 'for'],
#  ['eye', 'gel'],
#  ['gel', 'which'],
#  ['conditioner', 'gel'],
#  ['gel', 'spray'],
#  ['shampoo', 'conditioner'],
#  ['conditioner', 'gel'],
#  ['product', 'shampoo'],
#  ['shampoo', 'conditioner'],
#  ['gel', 'spray'],
#  ['spray', 'pill'],
#  ['and', 'blush'],
#  ['blush', 'since'],
#  ['the', 'blush'],
#  ['blush', 'very'],
#  ['body', 'lotion'],
#  ['lotion', '6'],
#  ['this', 'cream'],
#  ['cream', 'make'],
#  ['good', 'lipstick'],
#  ['this', 'candle'],
#  ['candle', 'several'],
#  ['these', 'candle'],
#  ['candle', 'since'],
#  ['aromatic', 'candle'],
#  ['candle', 'the'],
#  ['a', 'candle'],
#  ['candle', 'he'],
#  ['botanicals', 'candle'],
#  ['candle', 'and'],
#  ['this', 'candle'],
#  ['candle', 'smell'],
#  ['this', 'shampoo'],
#  ['shampoo', 'do'],
#  ['good', 'moisturizer'],
#  ['moisturizer', 'would'],
#  ['a', 'moisturizer'],
#  ['moisturizer', 'at'],
#  ['the', 'moisturizer'],
#  ['moisturizer', 'again'],
#  ['excess', 'oil'],
#  ['oil', 'be'],
#  ['a', 'soap'],
#  ['soap', 'dish'],
#  ['heavy', 'moisturizer'],
#  ['moisturizer', 'so'],
#  ['use', 'moisturizer'],
#  ['moisturizer', 'though'],
#  ['the', 'shampoo'],
#  ['shampoo', 'to'],
#  ['of', 'moisturizer'],
#  ['moisturizer', 'be'],
#  ['this', 'moisturizer'],
#  ['moisturizer', 'negate'],
#  ['liquidy', 'soap'],
#  ['soap', 'i'],
#  ['of', 'shampoo'],
#  ['shampoo', 'probably'],
#  ['shave', 'cream'],
#  ['cream', 'be'],
#  ['much', 'cream'],
#  ['cream', 'to'],
#  ['to', 'spray'],
#  ['spray', 'it'],
#  ['facial', 'cream'],
#  ['cream', 'fortify'],
#  ['this', 'cream'],
#  ['cream', 'because'],
#  ['perfect', 'moisturizer'],
#  ['moisturizer', 'with'],
#  ['nice', 'brush'],
#  ['brush', 'but'],
#  ['the', 'cream'],
#  ['cream', 'version'],
#  ['excellent', 'gel'],
#  ['gel', 'for'],
#  ['this', 'gel'],
#  ['loss', 'shampoo'],
#  ['shampoo', 'really'],
#  ['control', 'shampoo'],
#  ['facial', 'cream'],
#  ['cream', 'ever'],
#  ['cheap', 'cream'],
#  ['cream', 'or'],
#  ['colored', 'gel'],
#  ['gel', 'that'],
#  ['this', 'balm'],
#  ['balm', 'it'],
#  ['colorless', 'balm'],
#  ['balm', 'as'],
#  ['this', 'balm'],
#  ['balm', 'leave'],
#  ['and', 'moisturizer'],
#  ['moisturizer', 'for'],
#  ['a', 'moisturizer'],
#  ['moisturizer', 'that'],
#  ['an', 'oil'],
#  ['oil', 'slick'],
#  ['badger', 'brush'],
#  ['brush', 'for'],
#  ['this', 'brush'],
#  ['brush', 'be'],
#  ['the', 'brush'],
#  ['brush', 'they'],
#  ['the', 'brush'],
#  ['brush', 'i'],
#  ['the', 'brush'],
#  ['brush', 'be'],
#  ['the', 'brush'],
#  ['brush', 'these'],
#  ['these', 'brush'],
#  ['brush', 'be'],
#  ['the', 'brush'],
#  ['brush', 'you'],
#  ['another', 'shampoo'],
#  ['shampoo', 'to'],
#  ['this', 'mask'],
#  ['mask', 'be'],
#  ['the', 'oil'],
#  ['oil', 'throughout'],
#  ['pearson', 'brush'],
#  ['brush', 'make'],
#  ['heirloom', 'brush'],
#  ['brush', 'worth'],
#  ['pearson', 'brush'],
#  ['brush', 'include'],
#  ['cleaning', 'brush'],
#  ['brush', 'so'],
#  ['your', 'brush'],
#  ['brush', 'there'],
#  ['pearson', 'brush'],
#  ['brush', 'of'],
#  ['the', 'brush'],
#  ['brush', 'will'],
#  ['small', 'brush'],
#  ['brush', 'but'],
#  ['bristle', 'brush'],
#  ['brush', 'like'],
#  ['bristle', 'brush'],
#  ['brush', 'will'],
#  ['pearson', 'brush'],
#  ['brush', 'that'],
#  ['bristle', 'brush'],
#  ['brush', 'for'],
#  ['bristle', 'brush'],
#  ['brush', 'be'],
#  ['the', 'brush'],
#  ['brush', 'bristle'],
#  ['to', 'brush'],
#  ['brush', 'his'],
#  ['pearson', 'brush'],
#  ['brush', 'well'],
#  ['hair', 'brush'],
#  ['brush', 'by'],
#  ['this', 'candle'],
#  ['candle', 'finally'],
#  ['hydrating', 'cleanser'],
#  ['cleanser', 'because'],
#  ['solutions', 'moisturizer'],
#  ['moisturizer', 'and'],
#  ['shave', 'oil'],
#  ['oil', 'or'],
#  ['this', 'soap'],
#  ['soap', 'be'],
#  ['the', 'soap'],
#  ['soap', 'lather'],
#  ['the', 'soap'],
#  ['soap', 'cake'],
#  ['this', 'soap'],
#  ['soap', 'every'],
#  ['this', 'soap'],
#  ['soap', 'its'],
#  ['this', 'soap'],
#  ['soap', 'before'],
#  ['your', 'brush'],
#  ['brush', 'and'],
#  ['shave', 'lotion'],
#  ['lotion', 'i'],
#  ['hand', 'cream'],
#  ['cream', 'be'],
#  ['mint', 'soap'],
#  ['soap', 'hand'],
#  ['hand', 'soap'],
#  ['soap', 'and'],
#  ['and', 'lotion'],
#  ['lotion', 'be'],
#  ['this', 'candle'],
#  ['candle', 'make'],
#  ['hand', 'cream'],
#  ['cream', 'with'],
#  ['hand', 'cream'],
#  ['hand', 'moisturizer'],
#  ['moisturizer', 'i'],
#  ['this', 'moisturizer'],
#  ['moisturizer', 'leave'],
#  ['stonehenge', 'candle'],
#  ['candle', 'also'],
#  ['other', 'candle'],
#  ['candle', 'safety'],
#  ['cuticle', 'cream'],
#  ['cream', 'i'],
#  ['apply', 'lotion'],
#  ['lotion', 'or'],
#  ['angel', 'polish'],
#  ['polish', 'and'],
#  ['the', 'polish'],
#  ['polish', 'and'],
#  ['a', 'polish'],
#  ['polish', 'that'],
#  ['the', 'polish'],
#  ['polish', 'be'],
#  ['2', 'conditioner'],
#  ['conditioner', 'it'],
#  ['and', 'conditioner'],
#  ['conditioner', 'and'],
#  ['expensive', 'shampoo'],
#  ['shampoo', 'and'],
#  ['conditioning', 'cleanser'],
#  ['cleanser', 'to'],
#  ['and', 'oil'],
#  ['oil', 'but'],
#  ['this', 'balm'],
#  ['balm', 'will'],
#  ['the', 'balm'],
#  ['cleansing', 'conditioner'],
#  ['conditioner', 'and'],
#  ['good', 'shampoo'],
#  ['shampoo', 'for'],
#  ['eye', 'cream'],
#  ['cream', 'twice'],
#  ['the', 'spray'],
#  ['spray', 'version'],
#  ['on', 'concealer'],
#  ['concealer', 'and'],
#  ['baby', 'shampoo'],
#  ['shampoo', 'from'],
#  ['baby', 'shampoo'],
#  ['shampoo', 'this'],
#  ['their', 'shampoo'],
#  ['shampoo', 'one'],
#  ['vera', 'gel'],
#  ['gel', 'to'],
#  ['my', 'moisturizer'],
#  ['moisturizer', 'i'],
#  ['the', 'brush'],
#  ['brush', 'and'],
#  ['the', 'brush'],
#  ['brush', 'handle'],
#  ['of', 'brush'],
#  ['brush', 'over'],
#  ['good', 'brush'],
#  ['brush', 'i'],
#  ['nice', 'soap'],
#  ['soap', 'ever'],
#  ['hair', 'mask'],
#  ['mask', 'which'],
#  ['rich', 'gel'],
#  ['gel', 'it'],
#  ['other', 'shampoo'],
#  ['shampoo', 'as'],
#  ['other', 'shampoo'],
#  ['shampoo', 'almost'],
#  ['this', 'shampoo'],
#  ['shampoo', 'it'],
#  ['other', 'shampoo'],
#  ['shampoo', 'that'],
#  ['like', 'gel'],
#  ['gel', 'but'],
#  ['of', 'gel'],
#  ['gel', 'highly'],
#  ['finishing', 'spray'],
#  ['spray', 'i'],
#  ['every', 'shampoo'],
#  ['shampoo', 'mild'],
#  ['the', 'conditioner'],
#  ['conditioner', 'out'],
#  ['shaving', 'cream'],
#  ['cream', 'in'],
#  ['neutrogena', 'oil'],
#  ['oil', 'free'],
#  ['other', 'conditioner'],
#  ['conditioner', 'i'],
#  ['massage', 'oil'],
#  ['oil', 'spray'],
#  ['massage', 'oil'],
#  ['oil', 'so'],
#  ['the', 'shampoo'],
#  ['shampoo', 'body'],
#  ['1', 'shampoo'],
#  ['shampoo', 'body'],
#  ['the', 'shampoo'],
#  ['shampoo', 'be'],
#  ['oil', 'spray'],
#  ['spray', 'when'],
#  ['ionic', 'dryer'],
#  ['dryer', 'my'],
#  ['hair', 'dryer'],
#  ['dryer', 'of'],
#  ['another', 'dryer'],
#  ['dryer', 'on'],
#  ['face', 'cleanser'],
#  ['cleanser', 'and'],
#  ['right', 'lotion'],
#  ['lotion', 'too'],
#  ['little', 'lotion'],
#  ['lotion', 'will'],
#  ['other', 'lotion'],
#  ['lotion', 'the'],
#  ['with', 'concealer'],
#  ['this', 'brush'],
#  ['brush', 'it'],
#  ['perfect', 'brush'],
#  ['brush', 'great'],
#  ['iredale', 'brush'],
#  ['brush', 'cleaner'],
#  ['the', 'brush'],
#  ['brush', 'be'],
#  ['sheer', 'foundation'],
#  ['foundation', 'i'],
#  ['ivory', 'soap'],
#  ['soap', 'this'],
#  ['stelatopia', 'cream'],
#  ['cream', 'cleanser'],
#  ['moisturizing', 'cream'],
#  ['cream', 'for'],
#  ['cream', 'cleanser'],
#  ['cleanser', 'in'],
#  ['zoya', 'polish'],
#  ['polish', 'and'],
#  ['nail', 'polish'],
#  ['polish', 'bottle'],
#  ['amazing', 'shampoo'],
#  ['shampoo', 'leave'],
#  ['facial', 'cleanser'],
#  ['cleanser', 'it'],
#  ['great', 'cleanser'],
#  ['cleanser', 'for'],
#  ['extra', 'moisturizer'],
#  ['moisturizer', 'and'],
#  ['this', 'moisturizer'],
#  ['moisturizer', 'do'],
#  ['liquid', 'foundation'],
#  ['foundation', 'if'],
#  ['eye', 'cream'],
#  ['cream', 'and'],
#  ['emu', 'oil'],
#  ['oil', 'buy'],
#  ['nail', 'polish'],
#  ['polish', 'stay'],
#  ['face', 'moisturizer'],
#  ['moisturizer', 'and'],
#  ['this', 'moisturizer'],
#  ['moisturizer', 'be'],
#  ['a', 'blush'],
#  ['blush', 'for'],
#  ['my', 'brush'],
#  ['brush', 'regularly'],
#  ['wear', 'lipstick'],
#  ['lipstick', 'and'],
#  ['this', 'mascara'],
#  ['mascara', 'do'],
#  ['soothe', 'cream'],
#  ['cream', 'on'],
#  ['hold', 'cream'],
#  ['cream', 'on'],
#  ['hand', 'cream'],
#  ['cream', 'i'],
#  ['same', 'lipstick'],
#  ['lipstick', 'i'],
#  ['lip', 'balm'],
#  ['good', 'gel'],
#  ['gel', 'i'],
#  ['salon', 'gel'],
#  ['gel', 'to'],
#  ['good', 'gel'],
#  ['gel', 'leave'],
#  ['great', 'shampoo'],
#  ['shampoo', 'shampoo'],
#  ['shampoo', 'shampoo'],
#  ['shampoo', 'one'],
#  ['everyday', 'shampoo'],
#  ['shampoo', 'it'],
#  ['i', 'shampoo'],
#  ['shampoo', 'two'],
#  ['this', 'moisturizer'],
#  ['other', 'moisturizer'],
#  ['moisturizer', 'from'],
#  ['other', 'cream'],
#  ['cream', 'from'],
#  ['wear', 'foundation'],
#  ['foundation', 'daily'],
#  ['daily', 'shampoo'],
#  ['shampoo', 'or'],
#  ['the', 'lotion'],
#  ['lotion', 'from'],
#  ['art', 'mascara'],
#  ['mascara', 'be'],
#  ['other', 'mascara'],
#  ['mascara', 'may'],
#  ['great', 'foundation'],
#  ['foundation', 'light'],
#  ['almost', 'petroleum'],
#  ['petroleum', 'odor'],
#  ['and', 'lipstick'],
#  ['lipstick', 'i'],
#  ['this', 'cream'],
#  ['cream', 'on'],
#  ['aging', 'cream'],
#  ['cream', 'as'],
#  ['face', 'cleanser'],
#  ['cleanser', 'every'],
#  ['hair', 'dryer'],
#  ['dryer', 'to'],
#  ['hair', 'dryer'],
#  ['dryer', 'and'],
#  ['this', 'dryer'],
#  ['dryer', 'be'],
#  ['hair', 'dryer'],
#  ['dryer', 'availabe'],
#  ['chick', 'conditioner'],
#  ['conditioner', 'in'],
#  ['use', 'cream'],
#  ['cream', 'of'],
#  ['finishiing', 'cream'],
#  ['cream', 'wonderful'],
#  ['face', 'brush'],
#  ['brush', 'by'],
#  ['the', 'brush'],
#  ['brush', 'themselves'],
#  ['both', 'brush'],
#  ['brush', 'be'],
#  ['the', 'brush'],
#  ['brush', 'that'],
#  ['these', 'brush'],
#  ['brush', 'will'],
#  ['dermotologia', 'brush'],
#  ['brush', 'be'],
#  ['menscience', 'brush'],
#  ['brush', 'have'],
#  ['the', 'brush'],
#  ['brush', 'itself'],
#  ['menscience', 'brush'],
#  ['brush', 'indicate'],
#  ['dermotologia', 'brush'],
#  ['brush', 'have'],
#  ['the', 'brush'],
#  ['brush', 'the'],
#  ['menscience', 'brush'],
#  ['brush', 'have'],
#  ['the', 'brush'],
#  ['brush', 'so'],
#  ['menscience', 'brush'],
#  ['brush', 'have'],
#  ['case', 'brush'],
#  ['brush', 'become'],
#  ['this', 'brush'],
#  ['brush', 'that'],
#  ['face', 'brush'],
#  ['brush', 'they'],
#  ['abrasive', 'brush'],
#  ['brush', 'i'],
#  ['dermotologia', 'brush'],
#  ['the', 'lotion'],
#  ['lotion', 'leave'],
#  ['the', 'cream'],
#  ['cream', 'go'],
#  ['good', 'moisturizer'],
#  ['moisturizer', 'i'],
#  ['mer', 'moisturizer'],
#  ['moisturizer', 'which'],
#  ['many', 'moisturizer'],
#  ['moisturizer', 'it'],
#  ['face', 'moisturizer'],
#  ['moisturizer', 'fall'],
#  ['so', 'moisturizer'],
#  ['moisturizer', 'to'],
#  ['price', 'moisturizer'],
#  ['moisturizer', 'the'],
#  ['gel', 'cream'],
#  ['cream', 'be'],
#  ['morning', 'moisturizer'],
#  ['moisturizer', 'for'],
#  ['far', 'gel'],
#  ['gel', 'cream'],
#  ['a', 'gel'],
#  ['gel', 'but'],
#  ['tree', 'oil'],
#  ['oil', 'it'],
#  ['sunscreen', 'foundation'],
#  ['foundation', 'primer'],
#  ['rusk', 'spray'],
#  ['spray', 'be'],
#  ['a', 'moisturizer'],
#  ['moisturizer', 'but'],
#  ['as', 'brush'],
#  ['brush', 'it'],
#  ['hair', 'dryer'],
#  ['dryer', 'i'],
#  ['hair', 'dryer'],
#  ['dryer', 'but'],
#  ['old', 'dryer'],
#  ['dryer', 'and'],
#  ['face', 'cream'],
#  ['cream', 'i'],
#  ['wrinkle', 'concealer'],
#  ['concealer', 'but'],
#  ['stila', 'concealer'],
#  ['concealer', 'the'],
#  ['your', 'foundation'],
#  ['foundation', 'to'],
#  ['this', 'oil'],
#  ['oil', 'be'],
#  ['actually', 'spray'],
#  ['spray', 'chemical'],
#  ['moisturize', 'lotion'],
#  ['lotion', 'yet'],
#  ['like', 'moisturizer'],
#  ['moisturizer', 'without'],
#  ['the', 'conditioner'],
#  ['conditioner', 'be'],
#  ['in', 'conditioner'],
#  ['conditioner', 'when'],
#  ['the', 'conditioner'],
#  ['conditioner', 'between'],
#  ['kind', 'oil'],
#  ['any', 'soap'],
#  ['soap', 'residue'],
#  ['shave', 'cream'],
#  ['cream', 'my'],
#  ['the', 'candle'],
#  ['candle', 'arrive'],
#  ['those', 'cream'],
#  ['cream', 'where'],
#  ['rise', 'blush'],
#  ['blush', 'and'],
#  ['most', 'blush'],
#  ['blush', 'product'],
#  ['lightweight', 'blush'],
#  ['blush', 'look'],
#  ['small', 'blush'],
#  ['blush', 'brush'],
#  ['a', 'brush'],
#  ['brush', 'but'],
#  ['big', 'brush'],
#  ['brush', 'my'],
#  ['blush', 'brush'],
#  ['brush', 'two'],
#  ['styling', 'cream'],
#  ['cream', 'dp'],
#  ['styling', 'cream'],
#  ['cream', 'a'],
#  ['eye', 'cream'],
#  ['cream', 'this'],
#  ['eye', 'cream'],
#  ['cream', 'for'],
#  ['shaving', 'cream'],
#  ['cream', 'as'],
#  ['body', 'lotion'],
#  ['lotion', 'about'],
#  ['i', 'spray'],
#  ['spray', 'this'],
#  ['before', 'gel'],
#  ['gel', 'treatment'],
#  ['treatment', 'spray'],
#  ['spray', 'etc'],
#  ['rentinol', 'cream'],
#  ['cream', 'to'],
#  ['clean', 'brush'],
#  ['brush', 'get'],
#  ['normal', 'shampoo'],
#  ['shampoo', 'i'],
#  ['this', 'shampoo'],
#  ['shampoo', 'take'],
#  ['this', 'spray'],
#  ['spray', 'from'],
#  ['brow', 'gel'],
#  ['gel', 'it'],
#  ['shampoo', 'conditioner'],
#  ['conditioner', 'body'],
#  ['shampoo', 'conditioner'],
#  ['conditioner', 'remove'],
#  ['and', 'soap'],
#  ['soap', 'so'],
#  ['the', 'shampoo'],
#  ['shampoo', 'conditioner'],
#  ['clarify', 'shampoo'],
#  ['shampoo', 'conditioner'],
#  ['the', 'lotion'],
#  ['lotion', 'work'],
#  ['the', 'foundation'],
#  ['foundation', 'on'],
#  ['mousse', 'cream'],
#  ['cream', 'feel'],
#  ['lip', 'gloss'],
#  ['gloss', 'because'],
#  ['this', 'cleanser'],
#  ['cleanser', 'first'],
#  ['great', 'brush'],
#  ['brush', 'apply'],
#  ['brown', 'mascara'],
#  ['mascara', 'this'],
#  ['and', 'blush'],
#  ['blush', 'it'],
#  ['tan', 'spray'],
#  ['spray', 'system'],
#  ['volume', 'spray'],
#  ['spray', 'gun'],
#  ['the', 'spray'],
#  ['spray', 'gun'],
#  ['be', 'spray'],
#  ['spray', 'which'],
#  ['can', 'spray'],
#  ['spray', 'someone'],
#  ['standard', 'spray'],
#  ['spray', 'gun'],
#  ['eye', 'cream'],
#  ['cream', 'which'],
#  ['heavy', 'cream'],
#  ['cream', 'near'],
#  ['eye', 'cream'],
#  ['cream', 'and'],
#  ['eye', 'cream'],
#  ['cream', 'and'],
#  ['used', 'cream'],
#  ['cream', 'i'],
#  ['18', 'cream'],
#  ['cream', 'nothing'],
#  ['nothing', 'cream'],
#  ['cream', 'be'],
#  ['byebye', 'cream'],
#  ['first', 'spray'],
#  ['spray', 'bucheron'],
#  ['8', 'spray'],
#  ['spray', 'it'],
#  ['body', 'lotion'],
#  ['lotion', 'cologne'],
#  ['other', 'candle'],
#  ['candle', 'but'],
#  ['this', 'candle'],
#  ['candle', 'it'],
#  ['my', 'foundation'],
#  ['foundation', 'moderate'],
#  ['the', 'foundation'],
#  ['foundation', 'be'],
#  ['this', 'shampoo'],
#  ['shampoo', 'have'],
#  ['the', 'shampoo'],
#  ['shampoo', 'smell'],
#  ['a', 'brush'],
#  ['brush', 'through'],
#  ['about', 'mascara'],
#  ['mascara', 'and'],
#  ['the', 'dryer'],
#  ['dryer', 'have'],
#  ['hair', 'dryer'],
#  ['dryer', 'should'],
#  ['hair', 'dryer'],
#  ['dryer', 'that'],
#  ['nice', 'brush'],
#  ['brush', 'but'],
#  ['section', 'brush'],
#  ['brush', 'the'],
#  ['on', 'spray'],
#  ['spray', 'a'],
#  ['day', 'foundation'],
#  ['foundation', 'touch'],
#  ['clarify', 'shampoo'],
#  ['shaving', 'cream'],
#  ['cream', 'i'],
#  ['of', 'soap'],
#  ['soap', 'and'],
#  ['large', 'spray'],
#  ['spray', 'bottle'],
#  ['produce', 'oil'],
#  ['oil', 'to'],
#  ['olive', 'oil'],
#  ['oil', 'would'],
#  ['horrible', 'candle'],
#  ['candle', 'you'],
#  ['junk', 'candle'],
#  ['shave', 'oil'],
#  ['oil', 'be'],
#  ['shave', 'oil'],
#  ['oil', 'be'],
#  ['use', 'moisturizer'],
#  ['moisturizer', 'on'],
#  ['shave', 'balm'],
#  ['balm', 'i'],
#  ['shave', 'cream'],
#  ['cream', 'that'],
#  ['shave', 'cream'],
#  ['cream', 'and'],
#  ['shave', 'cream'],
#  ['cream', 'or'],
#  ['shave', 'cream'],
#  ['cream', 'since'],
#  ['other', 'cream'],
#  ['cream', 'and'],
#  ['or', 'gel'],
#  ['gel', 'and'],
#  ['and', 'gel'],
#  ['badger', 'brush'],
#  ['brush', 'with'],
#  ['shaving', 'cream'],
#  ['cream', 'shave'],
#  ['shaving', 'cream'],
#  ['cream', 'alone'],
#  ['shaving', 'oil'],
#  ['oil', 'as'],
#  ['the', 'oil'],
#  ['oil', 'then'],
#  ['the', 'oil'],
#  ['oil', 'and'],
#  ['shave', 'balm'],
#  ['balm', 'the'],
#  ['and', 'balm'],
#  ['balm', 'make'],
#  ['the', 'soap'],
#  ['soap', 'and'],
#  ['and', 'brush'],
#  ['brush', 'stand'],
#  ['shaving', 'oil'],
#  ['oil', 'and'],
#  ['the', 'oil'],
#  ['oil', 'work'],
#  ['the', 'oil'],
#  ['oil', 'seem'],
#  ['rub', 'oil'],
#  ['oil', 'on'],
#  ['normal', 'oil'],
#  ['oil', 'must'],
#  ['to', 'cream'],
#  ['cream', 'out'],
#  ['the', 'cream'],
#  ['cream', 'itself'],
#  ['the', 'cream'],
#  ['cream', 'which'],
#  ['s', 'cream'],
#  ['cream', 'name'],
#  ['good', 'brush'],
#  ['brush', 'and'],
#  ['damp', 'brush'],
#  ['brush', 'and'],
#  ['shave', 'cream'],
#  ['cream', 'for'],
#  ['shaving', 'cream'],
#  ['cream', 'jack'],
#  ['shave', 'soap'],
#  ['soap', 'and'],
#  ['the', 'soap'],
#  ['soap', 'last'],
#  ['and', 'soap'],
#  ['soap', 'for'],
#  ['badger', 'brush'],
#  ['brush', 'i'],
#  ['shave', 'oil'],
#  ['oil', 'in'],
#  ['preshave', 'oil'],
#  ['oil', 'badger'],
#  ['shave', 'oil'],
#  ['oil', 'on'],
#  ['shave', 'balm'],
#  ['balm', 'make'],
#  ['shave', 'soap'],
#  ['soap', 'straight'],
#  ['badger', 'brush'],
#  ['brush', 'shave'],
#  ['shave', 'gel'],
#  ['gel', 'i'],
#  ['gillette', 'gel'],
#  ['gel', 'this'],
#  ['this', 'foundation'],
#  ['foundation', 'i'],
#  ['this', 'foundation'],
#  ['foundation', 'base'],
#  ['excellent', 'foundation'],
#  ['foundation', 'the'],
#  ['the', 'lotion'],
#  ['lotion', 'because'],
#  ['great', 'conditioner'],
#  ['conditioner', 'for'],
#  ['hair', 'spray'],
#  ['spray', 'weigh'],
#  ['whip', 'cream'],
#  ['cream', 'and'],
#  ['facial', 'moisturizer'],
#  ['moisturizer', 'and'],
#  ['a', 'gel'],
#  ['gel', 'and'],
#  ['neuve', 'cream'],
#  ['cream', 'or'],
#  ['bioxygene', 'cream'],
#  ['effective', 'cleanser'],
#  ['cleanser', 'my'],
#  ['prescription', 'gel'],
#  ['gel', 'to'],
#  ['shaving', 'cream'],
#  ['cream', 'which'],
#  ['different', 'concealer'],
#  ['concealer', 'but'],
#  ['eye', 'concealer'],
#  ['concealer', 'work'],
#  ['the', 'concealer'],
#  ['concealer', 'the'],
#  ['small', 'brush'],
#  ['brush', 'not'],
#  ['this', 'shampoo'],
#  ['shampoo', 'clean'],
#  ['detangler', 'conditioner'],
#  ['conditioner', 'the'],
#  ['tangle', 'brush'],
#  ['brush', 'out'],
#  ['put', 'oil'],
#  ['oil', 'in'],
#  ['this', 'shampoo'],
#  ['shampoo', 'i'],
#  ['hair', 'spray'],
#  ['spray', 'be'],
#  ['this', 'shampoo'],
#  ['shampoo', 'i'],
#  ['moisturizing', 'shampoo'],
#  ['shampoo', 'because'],
#  ['new', 'shampoo'],
#  ['shampoo', 'it'],
#  ['the', 'shampoo'],
#  ['shampoo', 'and'],
#  ['soap', 'cleanser'],
#  ['cleanser', 'it'],
#  ['this', 'soap'],
#  ['soap', 'cleanser'],
#  ['a', 'mascara'],
#  ['mascara', 'that'],
#  ['this', 'mascara'],
#  ['mascara', 'be'],
#  ['lash', 'mascara'],
#  ['mascara', 'but'],
#  ['crease', 'brush'],
#  ['brush', 'it'],
#  ['original', 'shampoo'],
#  ...]

# %%
bigram_scores = nltk.collocations.BigramAssocMeasures()
bigrams_finder = nltk.collocations.BigramCollocationFinder.from_documents(bigrams)
bigrams_finder.apply_freq_filter(10)

# %%
DICE = bigrams_finder.score_ngrams(bigram_scores.dice)
PMI = bigrams_finder.score_ngrams(bigram_scores.pmi)
CHI_SQ = bigrams_finder.score_ngrams(bigram_scores.chi_sq)

# %%
for i in DICE[:20]:
  print(i)
# Out:
# (('lip', 'balm'), 0.2980769230769231)
# (('lip', 'gloss'), 0.296551724137931)
# (('nail', 'polish'), 0.28950276243093925)
# (('hair', 'dryer'), 0.21267893660531698)
# (('blow', 'dryer'), 0.19950124688279303)
# (('this', 'shampoo'), 0.13285024154589373)
# (('shower', 'gel'), 0.12857142857142856)
# (('shampoo', 'and'), 0.11399832355406538)
# (('the', 'brush'), 0.09992313604919292)
# (('and', 'conditioner'), 0.08982683982683982)
# (('the', 'shampoo'), 0.08571428571428572)
# (('brush', 'be'), 0.08539944903581267)
# (('hair', 'spray'), 0.08442211055276382)
# (('this', 'lotion'), 0.08288639687957094)
# (('this', 'cream'), 0.079816813869807)
# (('the', 'lotion'), 0.07666506947771921)
# (('a', 'moisturizer'), 0.07333333333333333)
# (('my', 'foundation'), 0.0718562874251497)
# (('lotion', 'be'), 0.07095610342754059)
# (('facial', 'cleanser'), 0.07085346215780998)

# %%
for j in PMI[:20]:
  print(j)
# Out:
# (('blow', 'dryer'), 6.3572658975193)
# (('lip', 'gloss'), 6.018686025479756)
# (('mud', 'mask'), 5.825736508378585)
# (('lip', 'balm'), 5.7676444604767525)
# (('shower', 'gel'), 5.311053643353663)
# (('nail', 'polish'), 5.209566950592166)
# (('liquid', 'foundation'), 5.100108058022174)
# (('hair', 'dryer'), 5.082102269967857)
# (('gentle', 'cleanser'), 5.073587181769481)
# (('polish', 'remover'), 5.070961712362658)
# (('essential', 'oil'), 4.916076110384489)
# (('tinted', 'moisturizer'), 4.8518706541164605)
# (('an', 'oil'), 4.723431032442093)
# (('coconut', 'oil'), 4.6750680108806915)
# (('spray', 'bottle'), 4.459095027939842)
# (('pearson', 'brush'), 4.328236848907768)
# (('brush', 'head'), 4.190733325157831)
# (('bristle', 'brush'), 4.135591770965373)
# (('facial', 'cleanser'), 4.073587181769481)
# (('badger', 'brush'), 4.065202443073973)

# %%
for k in CHI_SQ[:20]:
  print(k)
# Out:
# (('nail', 'polish'), 4729.864038979352)
# (('lip', 'balm'), 3300.130300048315)
# (('blow', 'dryer'), 3242.769145090593)
# (('lip', 'gloss'), 2728.6367056919976)
# (('shower', 'gel'), 1737.7617434083265)
# (('hair', 'dryer'), 1686.1477007373014)
# (('mud', 'mask'), 891.049640592884)
# (('eye', 'cream'), 755.1504891417104)
# (('hand', 'cream'), 571.4149568828194)
# (('polish', 'remover'), 552.2534434075402)
# (('liquid', 'foundation'), 526.5064172610499)
# (('shaving', 'cream'), 460.7244495848057)
# (('night', 'cream'), 459.11346896139077)
# (('hair', 'spray'), 410.84426968196817)
# (('gentle', 'cleanser'), 355.4041610487329)
# (('an', 'oil'), 354.29325188072164)
# (('spray', 'bottle'), 351.0389078383762)
# (('essential', 'oil'), 350.4384088964927)
# (('body', 'lotion'), 338.87659856843874)
# (('facial', 'cleanser'), 334.58045441241484)

# %% [markdown]
# **Группировка коллокаций - биграммы**

# %%
collocations_bigrams = {}
for lux in full_lux:
  collocations_bigrams[lux] = []
for bigram in DICE:
  words = set(list(bigram[0])) & full_lux
  for word in words:
    collocations_bigrams[word].append(' '.join(bigram[0]))
for lux in full_lux:
  collocations_bigrams[lux] = list(set(collocations_bigrams[lux]))
for word in ['cream', 'brush', 'shampoo', 'conditioner', 'gel', 'lotion', 'cleanser']:
  print(word)
  for i in collocations_bigrams[word]:
    print('\t'+i)
# Out:
# cream
# 	shaving cream
# 	face cream
# 	and cream
# 	cream have
# 	cream this
# 	cream and
# 	cc cream
# 	day cream
# 	cream for
# 	cream i
# 	a cream
# 	cream in
# 	the cream
# 	night cream
# 	cream do
# 	cream which
# 	body cream
# 	cream blush
# 	hand cream
# 	lotion cream
# 	cream the
# 	cream but
# 	cream be
# 	cream to
# 	cream it
# 	cream with
# 	neck cream
# 	eye cream
# 	cream that
# 	cream on
# 	bb cream
# 	this cream
# 	cream cleanser
# 	shave cream
# brush
# 	brush head
# 	brush i
# 	good brush
# 	bristle brush
# 	to brush
# 	brush be
# 	foundation brush
# 	brush the
# 	these brush
# 	a brush
# 	my brush
# 	brush my
# 	pearson brush
# 	brush have
# 	brush it
# 	brush that
# 	badger brush
# 	and brush
# 	brush will
# 	the brush
# 	brush on
# 	brush do
# 	brush in
# 	blush brush
# 	brush to
# 	brush but
# 	brush from
# 	brush and
# 	brush for
# 	great brush
# 	this brush
# shampoo
# 	the shampoo
# 	shampoo be
# 	shampoo it
# 	a shampoo
# 	shampoo in
# 	shampoo conditioner
# 	great shampoo
# 	shampoo leave
# 	shampoo for
# 	good shampoo
# 	shampoo to
# 	of shampoo
# 	other shampoo
# 	to shampoo
# 	shampoo i
# 	shampoo and
# 	shampoo but
# 	this shampoo
# 	shampoo that
# 	shampoo with
# 	dry shampoo
# 	shampoo do
# conditioner
# 	and conditioner
# 	good conditioner
# 	conditioner for
# 	shampoo conditioner
# 	conditioner that
# 	conditioner to
# 	this conditioner
# 	conditioner my
# 	conditioner and
# 	conditioner i
# 	conditioner it
# 	a conditioner
# 	in conditioner
# 	conditioner be
# 	the conditioner
# gel
# 	a gel
# 	gel to
# 	shower gel
# 	this gel
# 	gel and
# 	gel for
# 	the gel
# 	gel be
# 	gel i
# 	gel it
# 	gel polish
# lotion
# 	lotion for
# 	hand lotion
# 	lotion be
# 	lotion i
# 	lotion but
# 	lotion with
# 	good lotion
# 	a lotion
# 	lotion it
# 	lotion that
# 	body lotion
# 	this lotion
# 	lotion cream
# 	lotion on
# 	lotion the
# 	the lotion
# 	and lotion
# 	of lotion
# 	lotion and
# cleanser
# 	cleanser that
# 	facial cleanser
# 	cleanser for
# 	cleanser be
# 	gentle cleanser
# 	cleanser and
# 	cleanser i
# 	a cleanser
# 	face cleanser
# 	cream cleanser
# 	this cleanser
# 	the cleanser
# 	cleanser it

# %% [markdown]
# Кажется, что особых различий между DICE, PMI и CHI_SQ нет. На мой взгляд DICE работает немного лучше, если посмотреть, например, на cleanser. Особенно для cream он выделяет неплохие сочетания: назначения, разные прилагательные отношения к продукты, прилагательные, относящиеся к описанию самого продукта и тд.

# %% [markdown]
# **Триграммы**

# %%
trigrams = []

for i, review in enumerate(tqdm(data_preprocessed['reviewText'])):
  review = review.split()
  for lux in full_lux:
    line = []
    for i, word in enumerate(review):
      if word == lux:
        line.append(i)
    if line:
      for i in line:
        if i != 0:
          trigrams.append(review[(i - 1):(i + 2)])
# Out:
# 100%|██████████| 12111/12111 [00:02<00:00, 4140.91it/s]

# %%
trigrams
# Out:
# [['hand', 'cream', 'and'],
#  ['hand', 'cream', 'be'],
#  ['good', 'soap', 'for'],
#  ['evelyn', 'soap', 'for'],
#  ['pump', 'soap', 'could'],
#  ['wrong', 'soap', 'hope'],
#  ['this', 'lotion'],
#  ['different', 'lotion', 'but'],
#  ['try', 'cream', 'natural'],
#  ['mineral', 'cream', 'yoga'],
#  ['generic', 'moisturizer', 'for'],
#  ['regular', 'moisturizer', 'it'],
#  ['blow', 'dryer', 'speed'],
#  ['counter', 'cream', 'i'],
#  ['nail', 'polish', 'once'],
#  ['nail', 'polish', 'it'],
#  ['this', 'polish', 'under'],
#  ['this', 'polish', 'i'],
#  ['good', 'polish', 'i'],
#  ['this', 'polish', 'as'],
#  ['glitter', 'polish', 'this'],
#  ['other', 'polish', 'but'],
#  ['the', 'mascara', 'when'],
#  ['night', 'cream', 'it'],
#  ['from', 'foundation', 'up'],
#  ['silkcoat', 'balm', 'i'],
#  ['silkcoat', 'balm', 'only'],
#  ['silkcoat', 'balm', 'it'],
#  ['good', 'lotion', 'ever'],
#  ['of', 'foundation', 'and'],
#  ['my', 'cleanser', 'this'],
#  ['this', 'soap', 'be'],
#  ['too', 'soap', 'disappear'],
#  ['novelty', 'soap'],
#  ['algae', 'cleanser', 'first'],
#  ['this', 'shampoo', 'work'],
#  ['bad', 'conditioner', 'for'],
#  ['terrific', 'shampoo', 'you'],
#  ['best', 'shampoo', 'and'],
#  ['smell', 'shampoo', 'i'],
#  ['this', 'shampoo'],
#  ['of', 'spray', 'would'],
#  ['this', 'cleanser', 'in'],
#  ['after', 'spray', 'so'],
#  ['spread', 'foundation', 'perfectly'],
#  ['this', 'brush', 'year'],
#  ['first', 'brush', 'i'],
#  ['i', 'mascara', 'even'],
#  ['the', 'brush', 'when'],
#  ['this', 'brush', 'be'],
#  ['these', 'brushes', 'for'],
#  ['other', 'brushes', 'this'],
#  ['best', 'brush', 'in'],
#  ['the', 'brush', 'cleans'],
#  ['liquid', 'foundation', 'it'],
#  ['to', 'foundation', 'that'],
#  ['and', 'moisturizer', 'so'],
#  ['separate', 'moisturizer', 'and'],
#  ['than', 'lipstick', 'i'],
#  ['apply', 'lotion', 'of'],
#  ['nice', 'blush', 'i'],
#  ['shave', 'cream', 'and'],
#  ['the', 'gel', 'be'],
#  ['s', 'gel', 'the'],
#  ['shave', 'oil', 'the'],
#  ['shave', 'oil', 'anthony'],
#  ['this', 'concealer', 'for'],
#  ['this', 'lotion', 'for'],
#  ['other', 'lotion', 'loose'],
#  ['favorite', 'blush', 'unfortunatley'],
#  ['the', 'blush', 'so'],
#  ['good', 'lotion', 'for'],
#  ['murad', 'lotion', 'i'],
#  ['face', 'cream', 'over'],
#  ['in', 'conditioner', 'and'],
#  ['this', 'cream', 'for'],
#  ['this', 'blush', 'for'],
#  ['amazing', 'blush', 'for'],
#  ['my', 'brush', 'swipe'],
#  ['hair', 'spray', 'like'],
#  ['regular', 'lotion', 'when'],
#  ['this', 'moisturizer', 'for'],
#  ['eye', 'gel', 'which'],
#  ['conditioner', 'gel', 'spray'],
#  ['shampoo', 'conditioner', 'gel'],
#  ['product', 'shampoo', 'conditioner'],
#  ['gel', 'spray', 'pill'],
#  ['and', 'blush', 'since'],
#  ['the', 'blush', 'very'],
#  ['body', 'lotion', '6'],
#  ['this', 'cream', 'make'],
#  ['good', 'lipstick'],
#  ['this', 'candle', 'several'],
#  ['these', 'candle', 'since'],
#  ['aromatic', 'candle', 'the'],
#  ['a', 'candle', 'he'],
#  ['botanicals', 'candle', 'and'],
#  ['this', 'candle', 'smell'],
#  ['this', 'shampoo', 'do'],
#  ['good', 'moisturizer', 'would'],
#  ['a', 'moisturizer', 'at'],
#  ['the', 'moisturizer', 'again'],
#  ['excess', 'oil', 'be'],
#  ['a', 'soap', 'dish'],
#  ['heavy', 'moisturizer', 'so'],
#  ['use', 'moisturizer', 'though'],
#  ['the', 'shampoo', 'to'],
#  ['of', 'moisturizer', 'be'],
#  ['this', 'moisturizer', 'negate'],
#  ['liquidy', 'soap', 'i'],
#  ['of', 'shampoo', 'probably'],
#  ['shave', 'cream', 'be'],
#  ['much', 'cream', 'to'],
#  ['to', 'spray', 'it'],
#  ['facial', 'cream', 'fortify'],
#  ['this', 'cream', 'because'],
#  ['perfect', 'moisturizer', 'with'],
#  ['nice', 'brush', 'but'],
#  ['the', 'cream', 'version'],
#  ['excellent', 'gel', 'for'],
#  ['this', 'gel'],
#  ['loss', 'shampoo', 'really'],
#  ['control', 'shampoo'],
#  ['facial', 'cream', 'ever'],
#  ['cheap', 'cream', 'or'],
#  ['colored', 'gel', 'that'],
#  ['this', 'balm', 'it'],
#  ['colorless', 'balm', 'as'],
#  ['this', 'balm', 'leave'],
#  ['and', 'moisturizer', 'for'],
#  ['a', 'moisturizer', 'that'],
#  ['an', 'oil', 'slick'],
#  ['badger', 'brush', 'for'],
#  ['this', 'brush', 'be'],
#  ['the', 'brush', 'they'],
#  ['the', 'brush', 'i'],
#  ['the', 'brush', 'be'],
#  ['the', 'brush', 'these'],
#  ['these', 'brush', 'be'],
#  ['the', 'brush', 'you'],
#  ['another', 'shampoo', 'to'],
#  ['this', 'mask', 'be'],
#  ['the', 'oil', 'throughout'],
#  ['pearson', 'brush', 'make'],
#  ['heirloom', 'brush', 'worth'],
#  ['pearson', 'brush', 'include'],
#  ['cleaning', 'brush', 'so'],
#  ['your', 'brush', 'there'],
#  ['pearson', 'brush', 'of'],
#  ['the', 'brush', 'will'],
#  ['small', 'brush', 'but'],
#  ['bristle', 'brush', 'like'],
#  ['bristle', 'brush', 'will'],
#  ['pearson', 'brush', 'that'],
#  ['bristle', 'brush', 'for'],
#  ['bristle', 'brush', 'be'],
#  ['the', 'brush', 'bristle'],
#  ['to', 'brush', 'his'],
#  ['pearson', 'brush', 'well'],
#  ['hair', 'brush', 'by'],
#  ['this', 'candle', 'finally'],
#  ['hydrating', 'cleanser', 'because'],
#  ['solutions', 'moisturizer', 'and'],
#  ['shave', 'oil', 'or'],
#  ['this', 'soap', 'be'],
#  ['the', 'soap', 'lather'],
#  ['the', 'soap', 'cake'],
#  ['this', 'soap', 'every'],
#  ['this', 'soap', 'its'],
#  ['this', 'soap', 'before'],
#  ['your', 'brush', 'and'],
#  ['shave', 'lotion', 'i'],
#  ['hand', 'cream', 'be'],
#  ['mint', 'soap', 'hand'],
#  ['hand', 'soap', 'and'],
#  ['and', 'lotion', 'be'],
#  ['this', 'candle', 'make'],
#  ['hand', 'cream', 'with'],
#  ['hand', 'cream'],
#  ['hand', 'moisturizer', 'i'],
#  ['this', 'moisturizer', 'leave'],
#  ['stonehenge', 'candle', 'also'],
#  ['other', 'candle', 'safety'],
#  ['cuticle', 'cream', 'i'],
#  ['apply', 'lotion', 'or'],
#  ['angel', 'polish', 'and'],
#  ['the', 'polish', 'and'],
#  ['a', 'polish', 'that'],
#  ['the', 'polish', 'be'],
#  ['2', 'conditioner', 'it'],
#  ['and', 'conditioner', 'and'],
#  ['expensive', 'shampoo', 'and'],
#  ['conditioning', 'cleanser', 'to'],
#  ['and', 'oil', 'but'],
#  ['this', 'balm', 'will'],
#  ['the', 'balm'],
#  ['cleansing', 'conditioner', 'and'],
#  ['good', 'shampoo', 'for'],
#  ['eye', 'cream', 'twice'],
#  ['the', 'spray', 'version'],
#  ['on', 'concealer', 'and'],
#  ['baby', 'shampoo', 'from'],
#  ['baby', 'shampoo', 'this'],
#  ['their', 'shampoo', 'one'],
#  ['vera', 'gel', 'to'],
#  ['my', 'moisturizer', 'i'],
#  ['the', 'brush', 'and'],
#  ['the', 'brush', 'handle'],
#  ['of', 'brush', 'over'],
#  ['good', 'brush', 'i'],
#  ['nice', 'soap', 'ever'],
#  ['hair', 'mask', 'which'],
#  ['rich', 'gel', 'it'],
#  ['other', 'shampoo', 'as'],
#  ['other', 'shampoo', 'almost'],
#  ['this', 'shampoo', 'it'],
#  ['other', 'shampoo', 'that'],
#  ['like', 'gel', 'but'],
#  ['of', 'gel', 'highly'],
#  ['finishing', 'spray', 'i'],
#  ['every', 'shampoo', 'mild'],
#  ['the', 'conditioner', 'out'],
#  ['shaving', 'cream', 'in'],
#  ['neutrogena', 'oil', 'free'],
#  ['other', 'conditioner', 'i'],
#  ['massage', 'oil', 'spray'],
#  ['massage', 'oil', 'so'],
#  ['the', 'shampoo', 'body'],
#  ['1', 'shampoo', 'body'],
#  ['the', 'shampoo', 'be'],
#  ['oil', 'spray', 'when'],
#  ['ionic', 'dryer', 'my'],
#  ['hair', 'dryer', 'of'],
#  ['another', 'dryer', 'on'],
#  ['face', 'cleanser', 'and'],
#  ['right', 'lotion', 'too'],
#  ['little', 'lotion', 'will'],
#  ['other', 'lotion', 'the'],
#  ['with', 'concealer'],
#  ['this', 'brush', 'it'],
#  ['perfect', 'brush', 'great'],
#  ['iredale', 'brush', 'cleaner'],
#  ['the', 'brush', 'be'],
#  ['sheer', 'foundation', 'i'],
#  ['ivory', 'soap', 'this'],
#  ['stelatopia', 'cream', 'cleanser'],
#  ['moisturizing', 'cream', 'for'],
#  ['cream', 'cleanser', 'in'],
#  ['zoya', 'polish', 'and'],
#  ['nail', 'polish', 'bottle'],
#  ['amazing', 'shampoo', 'leave'],
#  ['facial', 'cleanser', 'it'],
#  ['great', 'cleanser', 'for'],
#  ['extra', 'moisturizer', 'and'],
#  ['this', 'moisturizer', 'do'],
#  ['liquid', 'foundation', 'if'],
#  ['eye', 'cream', 'and'],
#  ['emu', 'oil', 'buy'],
#  ['nail', 'polish', 'stay'],
#  ['face', 'moisturizer', 'and'],
#  ['this', 'moisturizer', 'be'],
#  ['a', 'blush', 'for'],
#  ['my', 'brush', 'regularly'],
#  ['wear', 'lipstick', 'and'],
#  ['this', 'mascara', 'do'],
#  ['soothe', 'cream', 'on'],
#  ['hold', 'cream', 'on'],
#  ['hand', 'cream', 'i'],
#  ['same', 'lipstick', 'i'],
#  ['lip', 'balm'],
#  ['good', 'gel', 'i'],
#  ['salon', 'gel', 'to'],
#  ['good', 'gel', 'leave'],
#  ['great', 'shampoo', 'shampoo'],
#  ['shampoo', 'shampoo', 'one'],
#  ['everyday', 'shampoo', 'it'],
#  ['i', 'shampoo', 'two'],
#  ['this', 'moisturizer'],
#  ['other', 'moisturizer', 'from'],
#  ['other', 'cream', 'from'],
#  ['wear', 'foundation', 'daily'],
#  ['daily', 'shampoo', 'or'],
#  ['the', 'lotion', 'from'],
#  ['art', 'mascara', 'be'],
#  ['other', 'mascara', 'may'],
#  ['great', 'foundation', 'light'],
#  ['almost', 'petroleum', 'odor'],
#  ['and', 'lipstick', 'i'],
#  ['this', 'cream', 'on'],
#  ['aging', 'cream', 'as'],
#  ['face', 'cleanser', 'every'],
#  ['hair', 'dryer', 'to'],
#  ['hair', 'dryer', 'and'],
#  ['this', 'dryer', 'be'],
#  ['hair', 'dryer', 'availabe'],
#  ['chick', 'conditioner', 'in'],
#  ['use', 'cream', 'of'],
#  ['finishiing', 'cream', 'wonderful'],
#  ['face', 'brush', 'by'],
#  ['the', 'brush', 'themselves'],
#  ['both', 'brush', 'be'],
#  ['the', 'brush', 'that'],
#  ['these', 'brush', 'will'],
#  ['dermotologia', 'brush', 'be'],
#  ['menscience', 'brush', 'have'],
#  ['the', 'brush', 'itself'],
#  ['menscience', 'brush', 'indicate'],
#  ['dermotologia', 'brush', 'have'],
#  ['the', 'brush', 'the'],
#  ['menscience', 'brush', 'have'],
#  ['the', 'brush', 'so'],
#  ['menscience', 'brush', 'have'],
#  ['case', 'brush', 'become'],
#  ['this', 'brush', 'that'],
#  ['face', 'brush', 'they'],
#  ['abrasive', 'brush', 'i'],
#  ['dermotologia', 'brush'],
#  ['the', 'lotion', 'leave'],
#  ['the', 'cream', 'go'],
#  ['good', 'moisturizer', 'i'],
#  ['mer', 'moisturizer', 'which'],
#  ['many', 'moisturizer', 'it'],
#  ['face', 'moisturizer', 'fall'],
#  ['so', 'moisturizer', 'to'],
#  ['price', 'moisturizer', 'the'],
#  ['gel', 'cream', 'be'],
#  ['morning', 'moisturizer', 'for'],
#  ['far', 'gel', 'cream'],
#  ['a', 'gel', 'but'],
#  ['tree', 'oil', 'it'],
#  ['sunscreen', 'foundation', 'primer'],
#  ['rusk', 'spray', 'be'],
#  ['a', 'moisturizer', 'but'],
#  ['as', 'brush', 'it'],
#  ['hair', 'dryer', 'i'],
#  ['hair', 'dryer', 'but'],
#  ['old', 'dryer', 'and'],
#  ['face', 'cream', 'i'],
#  ['wrinkle', 'concealer', 'but'],
#  ['stila', 'concealer', 'the'],
#  ['your', 'foundation', 'to'],
#  ['this', 'oil', 'be'],
#  ['actually', 'spray', 'chemical'],
#  ['moisturize', 'lotion', 'yet'],
#  ['like', 'moisturizer', 'without'],
#  ['the', 'conditioner', 'be'],
#  ['in', 'conditioner', 'when'],
#  ['the', 'conditioner', 'between'],
#  ['kind', 'oil'],
#  ['any', 'soap', 'residue'],
#  ['shave', 'cream', 'my'],
#  ['the', 'candle', 'arrive'],
#  ['those', 'cream', 'where'],
#  ['rise', 'blush', 'and'],
#  ['most', 'blush', 'product'],
#  ['lightweight', 'blush', 'look'],
#  ['small', 'blush', 'brush'],
#  ['a', 'brush', 'but'],
#  ['big', 'brush', 'my'],
#  ['blush', 'brush', 'two'],
#  ['styling', 'cream', 'dp'],
#  ['styling', 'cream', 'a'],
#  ['eye', 'cream', 'this'],
#  ['eye', 'cream', 'for'],
#  ['shaving', 'cream', 'as'],
#  ['body', 'lotion', 'about'],
#  ['i', 'spray', 'this'],
#  ['before', 'gel', 'treatment'],
#  ['treatment', 'spray', 'etc'],
#  ['rentinol', 'cream', 'to'],
#  ['clean', 'brush', 'get'],
#  ['normal', 'shampoo', 'i'],
#  ['this', 'shampoo', 'take'],
#  ['this', 'spray', 'from'],
#  ['brow', 'gel', 'it'],
#  ['shampoo', 'conditioner', 'body'],
#  ['shampoo', 'conditioner', 'remove'],
#  ['and', 'soap', 'so'],
#  ['the', 'shampoo', 'conditioner'],
#  ['clarify', 'shampoo', 'conditioner'],
#  ['the', 'lotion', 'work'],
#  ['the', 'foundation', 'on'],
#  ['mousse', 'cream', 'feel'],
#  ['lip', 'gloss', 'because'],
#  ['this', 'cleanser', 'first'],
#  ['great', 'brush', 'apply'],
#  ['brown', 'mascara', 'this'],
#  ['and', 'blush', 'it'],
#  ['tan', 'spray', 'system'],
#  ['volume', 'spray', 'gun'],
#  ['the', 'spray', 'gun'],
#  ['be', 'spray', 'which'],
#  ['can', 'spray', 'someone'],
#  ['standard', 'spray', 'gun'],
#  ['eye', 'cream', 'which'],
#  ['heavy', 'cream', 'near'],
#  ['eye', 'cream', 'and'],
#  ['eye', 'cream', 'and'],
#  ['used', 'cream', 'i'],
#  ['18', 'cream', 'nothing'],
#  ['nothing', 'cream', 'be'],
#  ['byebye', 'cream'],
#  ['first', 'spray', 'bucheron'],
#  ['8', 'spray', 'it'],
#  ['body', 'lotion', 'cologne'],
#  ['other', 'candle', 'but'],
#  ['this', 'candle', 'it'],
#  ['my', 'foundation', 'moderate'],
#  ['the', 'foundation', 'be'],
#  ['this', 'shampoo', 'have'],
#  ['the', 'shampoo', 'smell'],
#  ['a', 'brush', 'through'],
#  ['about', 'mascara', 'and'],
#  ['the', 'dryer', 'have'],
#  ['hair', 'dryer', 'should'],
#  ['hair', 'dryer', 'that'],
#  ['nice', 'brush', 'but'],
#  ['section', 'brush', 'the'],
#  ['on', 'spray', 'a'],
#  ['day', 'foundation', 'touch'],
#  ['clarify', 'shampoo'],
#  ['shaving', 'cream', 'i'],
#  ['of', 'soap', 'and'],
#  ['large', 'spray', 'bottle'],
#  ['produce', 'oil', 'to'],
#  ['olive', 'oil', 'would'],
#  ['horrible', 'candle', 'you'],
#  ['junk', 'candle'],
#  ['shave', 'oil', 'be'],
#  ['shave', 'oil', 'be'],
#  ['use', 'moisturizer', 'on'],
#  ['shave', 'balm', 'i'],
#  ['shave', 'cream', 'that'],
#  ['shave', 'cream', 'and'],
#  ['shave', 'cream', 'or'],
#  ['shave', 'cream', 'since'],
#  ['other', 'cream', 'and'],
#  ['or', 'gel', 'and'],
#  ['and', 'gel'],
#  ['badger', 'brush', 'with'],
#  ['shaving', 'cream', 'shave'],
#  ['shaving', 'cream', 'alone'],
#  ['shaving', 'oil', 'as'],
#  ['the', 'oil', 'then'],
#  ['the', 'oil', 'and'],
#  ['shave', 'balm', 'the'],
#  ['and', 'balm', 'make'],
#  ['the', 'soap', 'and'],
#  ['and', 'brush', 'stand'],
#  ['shaving', 'oil', 'and'],
#  ['the', 'oil', 'work'],
#  ['the', 'oil', 'seem'],
#  ['rub', 'oil', 'on'],
#  ['normal', 'oil', 'must'],
#  ['to', 'cream', 'out'],
#  ['the', 'cream', 'itself'],
#  ['the', 'cream', 'which'],
#  ['s', 'cream', 'name'],
#  ['good', 'brush', 'and'],
#  ['damp', 'brush', 'and'],
#  ['shave', 'cream', 'for'],
#  ['shaving', 'cream', 'jack'],
#  ['shave', 'soap', 'and'],
#  ['the', 'soap', 'last'],
#  ['and', 'soap', 'for'],
#  ['badger', 'brush', 'i'],
#  ['shave', 'oil', 'in'],
#  ['preshave', 'oil', 'badger'],
#  ['shave', 'oil', 'on'],
#  ['shave', 'balm', 'make'],
#  ['shave', 'soap', 'straight'],
#  ['badger', 'brush', 'shave'],
#  ['shave', 'gel', 'i'],
#  ['gillette', 'gel', 'this'],
#  ['this', 'foundation', 'i'],
#  ['this', 'foundation', 'base'],
#  ['excellent', 'foundation', 'the'],
#  ['the', 'lotion', 'because'],
#  ['great', 'conditioner', 'for'],
#  ['hair', 'spray', 'weigh'],
#  ['whip', 'cream', 'and'],
#  ['facial', 'moisturizer', 'and'],
#  ['a', 'gel', 'and'],
#  ['neuve', 'cream', 'or'],
#  ['bioxygene', 'cream'],
#  ['effective', 'cleanser', 'my'],
#  ['prescription', 'gel', 'to'],
#  ['shaving', 'cream', 'which'],
#  ['different', 'concealer', 'but'],
#  ['eye', 'concealer', 'work'],
#  ['the', 'concealer', 'the'],
#  ['small', 'brush', 'not'],
#  ['this', 'shampoo', 'clean'],
#  ['detangler', 'conditioner', 'the'],
#  ['tangle', 'brush', 'out'],
#  ['put', 'oil', 'in'],
#  ['this', 'shampoo', 'i'],
#  ['hair', 'spray', 'be'],
#  ['this', 'shampoo', 'i'],
#  ['moisturizing', 'shampoo', 'because'],
#  ['new', 'shampoo', 'it'],
#  ['the', 'shampoo', 'and'],
#  ['soap', 'cleanser', 'it'],
#  ['this', 'soap', 'cleanser'],
#  ['a', 'mascara', 'that'],
#  ['this', 'mascara', 'be'],
#  ['lash', 'mascara', 'but'],
#  ['crease', 'brush', 'it'],
#  ['original', 'shampoo', 'definitively'],
#  ['this', 'shampoo', 'from'],
#  ['this', 'conditioner', 'have'],
#  ['styling', 'cream', 'and'],
#  ['this', 'shampoo'],
#  ['this', 'oil', 'it'],
#  ['beautiful', 'oil', 'i'],
#  ['massage', 'oil'],
#  ['this', 'lotion', 'smell'],
#  ['cool', 'gel', 'give'],
#  ['excellent', 'oil', 'i'],
#  ['these', 'oil', 'one'],
#  ['the', 'oil', 'add'],
#  ['the', 'oil', 'blend'],
#  ['this', 'mask', 'especially'],
#  ['this', 'shampoo', 'it'],
#  ['the', 'blush', 'color'],
#  ['mineral', 'blush', 'and'],
#  ['the', 'blush', 'i'],
#  ['the', 'blush', 'i'],
#  ['makeup', 'blush', 'brand'],
#  ['makeup', 'blush', 'something'],
#  ['other', 'cleanser', 'i'],
#  ['this', 'cleanser', 'and'],
#  ['the', 'moisturizer'],
#  ['work', 'cream', 'that'],
#  ['looking', 'blush', 'for'],
#  ['this', 'foundation', 'be'],
#  ['facial', 'moisturizer', 'then'],
#  ['of', 'oil', 'control'],
#  ['with', 'oil', 'free'],
#  ['use', 'oil', 'absorbing'],
#  ['bullet', 'oil', 'absorbing'],
#  ['an', 'oil', 'free'],
#  ['pull', 'oil', 'out'],
#  ['have', 'oil', 'on'],
#  ['control', 'lotion', 'you'],
#  ['matting', 'lotion', 'i'],
#  ['the', 'lotion', 'only'],
#  ['free', 'lotion', 'and'],
#  ['clay', 'mask', 'and'],
#  ['facial', 'cleanser', 'and'],
#  ['cook', 'oil', 'on'],
#  ['conola', 'oil', 'cook'],
#  ['cook', 'oil', 'save'],
#  ['shaving', 'brush', 'in'],
#  ['3', 'brush', 'and'],
#  ['shaving', 'cream', 'leave'],
#  ['shave', 'balm', 'be'],
#  ['eye', 'cream', 'gel'],
#  ['cream', 'gel', 'but'],
#  ['a', 'candle', 'to'],
#  ['complexion', 'cream', 'the'],
#  ['seafoam', 'cream', 'mucho'],
#  ['excellent', 'cream', 'for'],
#  ['a', 'gel', 'it'],
#  ['skin', 'cream', 'for'],
#  ['firm', 'cream', 'available'],
#  ['c', 'cream', 'be'],
#  ['eye', 'cream', 'when'],
#  ['the', 'oil', 'get'],
#  ['this', 'cream', 'give'],
#  ['this', 'cream', 'but'],
#  ['cane', 'cream', 'and'],
#  ['save', 'oil', 'and'],
#  ['great', 'brush', 'make'],
#  ['this', 'shampoo', 'for'],
#  ['another', 'shampoo', 'a'],
#  ['stand', 'moisturizer', 'that'],
#  ['shave', 'cream', 'but'],
#  ['the', 'shampoo', 'and'],
#  ['light', 'moisturizer', 'and'],
#  ['good', 'moisturizer', 'i'],
#  ['real', 'moisturizer', 'i'],
#  ['this', 'cleanser', 'be'],
#  ['dermo', 'cleanser', 'be'],
#  ['skip', 'moisturizer', 'in'],
#  ['mineral', 'oil', 'and'],
#  ['mineral', 'oil', 'be'],
#  ['mineral', 'oil', 'cause'],
#  ['retinoid', 'cream'],
#  ['good', 'moisturizer', 'i'],
#  ['rebalance', 'cream', 'and'],
#  ['coat', 'balm', 'these'],
#  ['this', 'lotion', 'really'],
#  ['great', 'lipstick', 'box'],
#  ['mineral', 'foundation'],
#  ['up', 'brush', 'i'],
#  ['enough', 'moisturizer', 'foundation'],
#  ['moisturizer', 'foundation', 'etc'],
#  ['professional', 'brush', 'cleaner'],
#  ['their', 'brush', 'collection'],
#  ['great', 'polish', 'brand'],
#  ['shave', 'cream', 'and'],
#  ['shave', 'cream', 'i'],
#  ['shave', 'cream', 'the'],
#  ['the', 'cream', 'be'],
#  ['a', 'cream', 'that'],
#  ['light', 'cream', 'with'],
#  ['the', 'cream', 'have'],
#  ['facial', 'cleanser', 'and'],
#  ['face', 'cleanser', 'be'],
#  ['shave', 'oil', 'i'],
#  ['shave', 'oil', 'that'],
#  ['shave', 'oil', 'then'],
#  ['this', 'oil', 'i'],
#  ['shave', 'oil', 'even'],
#  ['shave', 'oil', 'give'],
#  ['an', 'oil', 'and'],
#  ['shave', 'oil', 'you'],
#  ['shave', 'oil', 'which'],
#  ['shave', 'oil', 'you'],
#  ['shave', 'oil', 'underneath'],
#  ['shave', 'oil', 'it'],
#  ['aftershave', 'balm', 'i'],
#  ['like', 'balm', 'after'],
#  ['this', 'balm', 'to'],
#  ['aftershave', 'balm', 'this'],
#  ['the', 'balm', 'with'],
#  ['good', 'shampoo', 'i'],
#  ['about', 'shampoo', 'i'],
#  ['the', 'oil', 'last'],
#  ['on', 'candle', 'inthe'],
#  ['the', 'lotion', 'be'],
#  ['the', 'lotion', 'have'],
#  ['shave', 'cream', 'i'],
#  ['show', 'gel', 'and'],
#  ['and', 'lotion', 'and'],
#  ['fragrant', 'candle', 'whenever'],
#  ['brush', 'soap', 'and'],
#  ['the', 'brush', 'soap'],
#  ['this', 'brush', 'to'],
#  ['this', 'brush', 'take'],
#  ['this', 'cleanser', 'every'],
#  ['this', 'brush', 'in'],
#  ['paddle', 'brush', 'i'],
#  ['this', 'brush', 'be'],
#  ['paddle', 'brush', 'from'],
#  ['paddle', 'brush', 'it'],
#  ['blow', 'dryer', 'so'],
#  ['hand', 'cream', 'i'],
#  ['of', 'cream', 'and'],
#  ['hand', 'cream'],
#  ['the', 'cream', 'get'],
#  ['more', 'shampoo', 'to'],
#  ['phyto', 'cream', 'for'],
#  ['much', 'cream', 'i'],
#  ['restructuring', 'mask', 'and'],
#  ['the', 'shampoo', 'and'],
#  ['different', 'shampoo', 'in'],
#  ['wonderful', 'cleanser', 'that'],
#  ['rose', 'moisturizer'],
#  ['this', 'mask', 'be'],
#  ['the', 'lotion', 'and'],
#  ['my', 'mascara', 'always'],
#  ['blinc', 'mascara', 'for'],
#  ['the', 'mascara', 'go'],
#  ['this', 'mascara', 'as'],
#  ['ok', 'mascara', 'not'],
#  ['cheap', 'mascara', 'that'],
#  ['this', 'mascara', 'retail'],
#  ['good', 'mascara', 'i'],
#  ['and', 'soap', 'seem'],
#  ['styling', 'cream', 'and'],
#  ['mega', 'gel', 'do'],
#  ['this', 'gel', 'do'],
#  ['this', 'gel', 'do'],
#  ['blow', 'dryer', 'and'],
#  ['this', 'shampoo', 'and'],
#  ['ahava', 'lotion', 'i'],
#  ['still', 'lotion', 'but'],
#  ['cuticle', 'cream', 'i'],
#  ['natural', 'soaps', 'htm'],
#  ['this', 'soap', 'bar'],
#  ['natural', 'soap', 'without'],
#  ['this', 'soap', 'also'],
#  ['this', 'soap', 'include'],
#  ['natural', 'soap', 'be'],
#  ['nice', 'soap', 'bar'],
#  ['hand', 'lotion', 'he'],
#  ['this', 'cream', 'actually'],
#  ['other', 'moisturizer', 'after'],
#  ['on', 'moisturizer', 'and'],
#  ['a', 'moisturizer', 'that'],
#  ['this', 'moisturizer', 'perform'],
#  ['with', 'moisturizer', 'for'],
#  ['hand', 'lotion', 'be'],
#  ['most', 'lotion', 'on'],
#  ['a', 'moisturizer', 'or'],
#  ['bath', 'oil', 'after'],
#  ['skin', 'cream', 'after'],
#  ['this', 'cleanser', 'it'],
#  ['this', 'cleanser', 'i'],
#  ['other', 'cleanser', 'that'],
#  ['eye', 'cream', 'i'],
#  ['this', 'cream', 'be'],
#  ['hand', 'cream', 'and'],
#  ['luxurious', 'cream', 'try'],
#  ['favorite', 'soap', 'my'],
#  ['most', 'soap', 'lotion'],
#  ['this', 'soap', 'do'],
#  ['soap', 'lotion', 'and'],
#  ['heavy', 'cream', 'this'],
#  ['more', 'moisturizer', 'but'],
#  ['facial', 'lotion', 'i'],
#  ['hand', 'lotion', 'version'],
#  ['hand', 'lotion', 'version'],
#  ['dandruff', 'shampoo', 'be'],
#  ['dandruff', 'shampoo', 'do'],
#  ['to', 'brush', 'your'],
#  ['ahava', 'shampoo', 'since'],
#  ['hand', 'cream', 'be'],
#  ['body', 'lotion', 'although'],
#  ['lip', 'brush', 'be'],
#  ['the', 'brush', 'retract'],
#  ['the', 'brush', 'end'],
#  ['body', 'lotion', 'together'],
#  ['the', 'conditioner', 'which'],
#  ['this', 'conditioner', 'and'],
#  ['this', 'conditioner', 'i'],
#  ['and', 'conditioner'],
#  ['the', 'shampoo', 'and'],
#  ['this', 'foundation', 'i'],
#  ['a', 'brush', 'on'],
#  ['use', 'brush', 'for'],
#  ['apply', 'lipstick'],
#  ['lip', 'balm', 'be'],
#  ['lip', 'balm', 'that'],
#  ['expensive', 'shampoo', 'work'],
#  ['these', 'lotion', 'at'],
#  ['sample', 'lotion', 'when'],
#  ['body', 'lotion', 'by'],
#  ['this', 'concealer', 'have'],
#  ['any', 'foundation', 'so'],
#  ['in', 'conditioner', 'to'],
#  ['plumping', 'gloss', 'i'],
#  ['good', 'brush', 'tip'],
#  ['great', 'conditioner', 'i'],
#  ['toning', 'shampoo', 'also'],
#  ['the', 'brush', 'be'],
#  ['and', 'shampoo', 'fill'],
#  ['grail', 'gel', 'i'],
#  ['hard', 'gel', 'after'],
#  ['of', 'conditioner', 'like'],
#  ['perfect', 'shampoo', 'to'],
#  ['good', 'shampoo', 'ever'],
#  ['my', 'moisturizer', 'since'],
#  ['this', 'oil', 'already'],
#  ['the', 'spray', 'bottle'],
#  ['a', 'spray', 'bottle'],
#  ['the', 'spray', 'button'],
#  ['pre', 'shampoo', 'treatment'],
#  ['magnolia', 'oil', 'omg'],
#  ['two', 'conditioner', 'worth'],
#  ['other', 'conditioner', 'come'],
#  ['this', 'conditioner', 'today'],
#  ['this', 'soap', 'be'],
#  ['full', 'lipstick', 'i'],
#  ['and', 'cream', 'makeup'],
#  ['color', 'concealer', 'and'],
#  ['own', 'brush', 'cleaner'],
#  ['a', 'brush', 'wet'],
#  ['the', 'brush', 'and'],
#  ['shave', 'cream', 'also'],
#  ['shave', 'oil', 'it'],
#  ['the', 'oil', 'be'],
#  ['this', 'oil', 'my'],
#  ['an', 'oil', 'it'],
#  ['shave', 'oil', 'need'],
#  ['or', 'lotion', 'that'],
#  ['a', 'lipstick', 'and'],
#  ['c', 'cream', 'and'],
#  ['wonderful', 'cream', 'especially'],
#  ['plastic', 'brush', 'and'],
#  ['this', 'polish', 'i'],
#  ['the', 'polish', 'be'],
#  ['nail', 'polish', 'color'],
#  ['this', 'polish', 'be'],
#  ['this', 'polish', 'it'],
#  ['your', 'polish', 'so'],
#  ['before', 'spray', 'to'],
#  ['free', 'polish', 'remover'],
#  ['free', 'polish', 'remover'],
#  ['this', 'polish', 'remover'],
#  ['other', 'spray', 'nail'],
#  ['nail', 'dryer', 'highly'],
#  ['for', 'oil', 'prone'],
#  ['shampoo', 'conditioner', 'for'],
#  ['shampoo', 'conditioner', 'be'],
#  ['featherweight', 'shampoo', 'conditioner'],
#  ['s', 'shampoo', 'conditioner'],
#  ['other', 'shampoo', 'or'],
#  ['quick', 'brush', 'and'],
#  ['hair', 'spray', 'so'],
#  ['and', 'soap', 'the'],
#  ['about', 'brush', 'be'],
#  ['the', 'brush', 'have'],
#  ['terrible', 'brush', 'i'],
#  ['these', 'brush', 'and'],
#  ['hair', 'spray', 'that'],
#  ['to', 'candle'],
#  ['hard', 'gel', 'once'],
#  ['hair', 'spray', 'or'],
#  ['when', 'shampoo', 'i'],
#  ['in', 'conditioner', 'i'],
#  ['to', 'shampoo', 'before'],
#  ['many', 'conditioner', 'out'],
#  ['this', 'lotion', 'and'],
#  ['the', 'lotion', 'itself'],
#  ['incredible', 'moisturizer', 'i'],
#  ['plant', 'oil', 'in'],
#  ['kernel', 'oil', 'and'],
#  ['nut', 'oil', 'boy'],
#  ['have', 'oil', 'in'],
#  ['this', 'lotion', 'non'],
#  ['body', 'lotion', 'the'],
#  ['only', 'lotion', 'that'],
#  ['other', 'lotion', 'compare'],
#  ['only', 'lotion', 'that'],
#  ['facial', 'cleanser', 'botanical'],
#  ['facial', 'gel', 'special'],
#  ['cleansing', 'lotion', 'c'],
#  ['cucumber', 'lotion', 'be'],
#  ['lotion', 'cream', 'and'],
#  ['cetaphil', 'cleanser', 'to'],
#  ['correcting', 'moisturizer', 'spf'],
#  ['of', 'lotion', 'cream'],
#  ['this', 'cleanser', 'from'],
#  ['this', 'cleanser', 'i'],
#  ['of', 'moisturizer', 'after'],
#  ['facial', 'moisturizer', 'and'],
#  ['product', 'spray', 'on'],
#  ['shaving', 'oil', 'but'],
#  ['much', 'oil', 'be'],
#  ['coconut', 'moisturizer', 'this'],
#  ['body', 'moisturizer', 'for'],
#  ['skin', 'oil', 'be'],
#  ['few', 'spray', 'after'],
#  ['this', 'soap', 'be'],
#  ['this', 'soap', 'be'],
#  ['hair', 'dryer', 'to'],
#  ['average', 'conditioner', 'it'],
#  ['aveeno', 'conditioner', 'but'],
#  ['the', 'lotion', 'be'],
#  ['a', 'spray', 'i'],
#  ['the', 'lotion', 'be'],
#  ['the', 'lotion', 'the'],
#  ['this', 'cleanser', 'it'],
#  ['eye', 'cream', 'all'],
#  ['astringent', 'lotion'],
#  ['excellent', 'concealer', 'for'],
#  ['hold', 'spray', 'it'],
#  ['hold', 'spray', 'i'],
#  ['super', 'spray', 'for'],
#  ['i', 'spray', 'it'],
#  ['scalp', 'shampoo', 'as'],
#  ['this', 'shampoo', 'do'],
#  ['like', 'soap', 'and'],
#  ['shave', 'gel'],
#  ['the', 'cleanser', 'i'],
#  ['a', 'cleanser', 'almost'],
#  ['the', 'cleanser', 'it'],
#  ['a', 'cleanser', 'should'],
#  ['a', 'moisturizer', 'but'],
#  ['wear', 'blush', 'drive'],
#  ['e', 'oil', 'and'],
#  ['cheapie', 'foundation', 'with'],
#  ['wear', 'foundation', 'doesn'],
#  ['mb', 'lotion', 'i'],
#  ['good', 'moisturizer', 'i'],
#  ['honey', 'moisturizer', 'have'],
#  ['this', 'moisturizer', 'do'],
#  ['and', 'oil', 'free'],
#  ['and', 'conditioner', 'i'],
#  ['enhancing', 'shampoo', 'and'],
#  ['this', 'shampoo', 'work'],
#  ['coconut', 'oil', 'work'],
#  ['this', 'gloss', 'it'],
#  ['this', 'brush', 'be'],
#  ['current', 'brush', 'seem'],
#  ['this', 'brush', 'i'],
#  ['pearson', 'brush', 'would'],
#  ['nice', 'lotion', 'i'],
#  ['but', 'soap', 'ooze'],
#  ['dry', 'shampoo', 'and'],
#  ['the', 'spray', 'can'],
#  ['your', 'polish', 'very'],
#  ['nail', 'polish', 'and'],
#  ['in', 'polish', 'that'],
#  ['my', 'polish', 'be'],
#  ['the', 'gel', 'be'],
#  ['the', 'lotion', 'and'],
#  ['the', 'oil', 'have'],
#  ['this', 'soap', 'from'],
#  ['this', 'soap', 'it'],
#  ['the', 'gel', 'seem'],
#  ['a', 'moisturizer', 'the'],
#  ['a', 'moisturizer', 'for'],
#  ['as', 'gel', 'i'],
#  ['hair', 'dryer', 'i'],
#  ['model', 'dryer', 'twice'],
#  ['exact', 'dryer', 'i'],
#  ['shower', 'gel', 'body'],
#  ['body', 'lotion', 'but'],
#  ['minute', 'mask', 'at'],
#  ['my', 'moisturizer', 'in'],
#  ['argan', 'oil'],
#  ['like', 'soap', 'i'],
#  ['the', 'lotion', 'actually'],
#  ['this', 'conditioner', 'make'],
#  ['to', 'brush', 'my'],
#  ['control', 'oil', 'secretion'],
#  ['silky', 'cleanser', 'that'],
#  ['face', 'moisturizer', 'be'],
#  ['even', 'mascara', 'i'],
#  ['love', 'candle', 'i'],
#  ['malone', 'candle', 'be'],
#  ['performing', 'candle', 'i'],
#  ['body', 'cleanser', 'the'],
#  ['conditioning', 'spray', 'like'],
#  ['the', 'shampoo', 'body'],
#  ['and', 'lotion', 'i'],
#  ['the', 'lotion', 'rub'],
#  ['the', 'gel', 'form'],
#  ['clear', 'mascara', 'could'],
#  ['expect', 'balm', 'and'],
#  ['a', 'balm', 'do'],
#  ['this', 'shampoo', 'for'],
#  ['this', 'gel', 'for'],
#  ['some', 'gel', 'on'],
#  ['the', 'gel', 'dry'],
#  ['strong', 'mask', 'which'],
#  ['with', 'foundation', 'or'],
#  ['the', 'brush', 'and'],
#  ['daily', 'moisturizer', 'it'],
#  ['apply', 'moisturizer', 'then'],
#  ['a', 'moisturizer', 'she'],
#  ['your', 'moisturizer', 'fully'],
#  ['standing', 'candle', 'just'],
#  ['this', 'candle', 'for'],
#  ['stonehenge', 'candle', 'that'],
#  ['black', 'candle', 'if'],
#  ['good', 'conditioner', 'on'],
#  ['protective', 'spray', 'be'],
#  ['my', 'foundation', 'just'],
#  ['face', 'lotion', 'i'],
#  ['in', 'conditioner', 'the'],
#  ['in', 'conditioner', 'at'],
#  ['the', 'spray', 'add'],
#  ['ocean', 'spray', 'this'],
#  ['this', 'conditioner', 'as'],
#  ['the', 'shampoo', 'love'],
#  ['face', 'moisturizer', 'really'],
#  ['one', 'shampoo', 'and'],
#  ['this', 'shampoo'],
#  ['could', 'brush', 'it'],
#  ['this', 'shampoo', 'for'],
#  ['like', 'conditioner', 'that'],
#  ['styling', 'cream', 'when'],
#  ['a', 'gel', 'that'],
#  ['light', 'conditioner', 'and'],
#  ['tinted', 'moisturizer', 'i'],
#  ['the', 'balm', 'products'],
#  ['unscented', 'cream', 'which'],
#  ['great', 'cream', 'for'],
#  ['tan', 'moisturizer', 'which'],
#  ['temporary', 'spray', 'bronzer'],
#  ['this', 'cleanser', 'for'],
#  ['of', 'cleanser', 'get'],
#  ['the', 'gel', 'like'],
#  ['the', 'gel', 'but'],
#  ['the', 'gel', 'morning'],
#  ['a', 'mascara', 'wand'],
#  ['avoid', 'mascara', 'during'],
#  ['remove', 'mascara', 'also'],
#  ['only', 'brush', 'my'],
#  ['fish', 'oil', 'and'],
#  ['fish', 'oil', 'free'],
#  ['fish', 'oil', 'go'],
#  ['fish', 'oil', 'and'],
#  ['fish', 'oil', 'to'],
#  ['the', 'gel', 'you'],
#  ['other', 'cleanser', 'i'],
#  ['this', 'cream', 'for'],
#  ['a', 'cleanser', 'toner'],
#  ['and', 'moisturizer', 'i'],
#  ['protein', 'spray', 'and'],
#  ['much', 'oil', 'or'],
#  ['to', 'spray', 'on'],
#  ['exfoliating', 'cream', 'for'],
#  ['orange', 'oil', 'and'],
#  ['to', 'moisturizer', 'the'],
#  ...]

# %%
trigrams_scores = nltk.collocations.TrigramAssocMeasures()
trigrams_finder = nltk.collocations.TrigramCollocationFinder.from_documents(trigrams)
trigrams_finder.apply_freq_filter(5)

# %%
JAC = trigrams_finder.score_ngrams(trigrams_scores.jaccard)
PMI = trigrams_finder.score_ngrams(trigrams_scores.pmi)
CHI_SQ = trigrams_finder.score_ngrams(trigrams_scores.chi_sq)

# %%
for l in JAC[:20]:
  print(l)
# Out:
# (('nail', 'polish', 'remover'), 0.02689486552567237)
# (('lip', 'gloss', 'do'), 0.01718213058419244)
# (('the', 'brush', 'be'), 0.015116811726981219)
# (('the', 'shampoo', 'and'), 0.014446227929373997)
# (('nail', 'polish', 'i'), 0.012476007677543186)
# (('this', 'shampoo', 'be'), 0.012304779933743492)
# (('nail', 'polish', 'but'), 0.011904761904761904)
# (('blow', 'dryer', 'i'), 0.010856453558504222)
# (('the', 'lotion', 'be'), 0.009571788413098237)
# (('lip', 'balm', 'i'), 0.009302325581395349)
# (('nail', 'polish', 'and'), 0.008955223880597015)
# (('this', 'shampoo', 'for'), 0.008094981111710739)
# (('a', 'spray', 'bottle'), 0.007905138339920948)
# (('hair', 'spray', 'or'), 0.007886435331230283)
# (('this', 'brush', 'be'), 0.0078125)
# (('lip', 'balm', 'and'), 0.007805724197745013)
# (('nail', 'polish', 'be'), 0.007759456838021339)
# (('this', 'lotion', 'be'), 0.007731958762886598)
# (('a', 'moisturizer', 'that'), 0.0075107296137339056)
# (('good', 'lotion', 'ever'), 0.00744047619047619)

# %%
for m in PMI[:20]:
  print(m)
# Out:
# (('nail', 'polish', 'remover'), 12.33175337282545)
# (('lip', 'gloss', 'do'), 10.871682313229591)
# (('blow', 'dryer', 'i'), 9.885350880430416)
# (('good', 'lotion', 'ever'), 9.72046620838524)
# (('a', 'spray', 'bottle'), 9.642293347668023)
# (('hair', 'spray', 'or'), 8.681650147722422)
# (('lip', 'gloss', 'be'), 8.567084096880144)
# (('lip', 'balm', 'i'), 8.473147215829744)
# (('neck', 'cream', 'i'), 8.410180684660943)
# (('nail', 'polish', 'but'), 8.386894927017913)
# (('lip', 'balm', 'and'), 8.11688342597607)
# (('the', 'spray', 'bottle'), 7.89740809020558)
# (('lip', 'gloss', 'the'), 7.839739420726836)
# (('lip', 'balm', 'be'), 7.808092196383939)
# (('shower', 'gel', 'be'), 7.76622036765621)
# (('hair', 'dryer', 'i'), 7.646713128904082)
# (('the', 'brush', 'itself'), 7.517904041050514)
# (('nail', 'polish', 'i'), 7.510985274742552)
# (('hair', 'dryer', 'and'), 7.342916758944543)
# (('shower', 'gel', 'and'), 7.227014690693387)

# %%
for n in CHI_SQ[:20]:
  print(n)
# Out:
# (('nail', 'polish', 'remover'), 62637.1268762811)
# (('lip', 'gloss', 'do'), 12515.28569333872)
# (('blow', 'dryer', 'i'), 11536.98772387564)
# (('nail', 'polish', 'but'), 8622.472852264187)
# (('nail', 'polish', 'i'), 8174.849276576276)
# (('nail', 'polish', 'and'), 7378.429605284583)
# (('nail', 'polish', 'be'), 7249.469548080384)
# (('nail', 'polish', 'it'), 7224.762907657892)
# (('lip', 'balm', 'i'), 6684.117692018052)
# (('lip', 'balm', 'and'), 6245.846976421951)
# (('lip', 'balm', 'be'), 5439.943329796501)
# (('lip', 'gloss', 'be'), 5126.601215773154)
# (('a', 'spray', 'bottle'), 5019.063809101074)
# (('good', 'lotion', 'ever'), 4966.210830762864)
# (('lip', 'gloss', 'the'), 4434.252742331756)
# (('hair', 'dryer', 'i'), 3292.2922536057977)
# (('hair', 'dryer', 'and'), 3148.0092526044245)
# (('shower', 'gel', 'be'), 3133.3581567824754)
# (('shower', 'gel', 'and'), 2815.887079795251)
# (('hair', 'spray', 'or'), 2537.4466906685857)

# %% [markdown]
# **Группировка коллокаций - триграммы**

# %%
collocations_trigrams = {}
for lux in full_lux:
  collocations_trigrams[lux] = []
for trigram in PMI:
  words = set(list(trigram[0])) & full_lux
  for word in words:
    collocations_trigrams[word].append(' '.join(trigram[0]))
for lux in full_lux:
  collocations_trigrams[lux] = list(set(collocations_trigrams[lux]))
for word in ['cream', 'brush', 'shampoo', 'conditioner', 'gel', 'lotion', 'cleanser']:
  print(word)
  for i in collocations_trigrams[word]:
    print('\t'+i)
# Out:
# cream
# 	this cream have
# 	hand cream i
# 	hand cream be
# 	this cream it
# 	this cream on
# 	night cream i
# 	this cream do
# 	eye cream be
# 	eye cream i
# 	this cream be
# 	eye cream and
# 	shaving cream and
# 	the cream and
# 	a cream that
# 	night cream and
# 	the cream be
# 	this cream for
# 	the cream have
# 	the cream i
# 	this cream i
# 	shaving cream i
# 	shave cream be
# 	shave cream and
# 	neck cream i
# brush
# 	the brush i
# 	the brush be
# 	the brush and
# 	the brush itself
# 	this brush be
# 	the brush that
# shampoo
# 	this shampoo have
# 	this shampoo i
# 	the shampoo conditioner
# 	this shampoo my
# 	this shampoo be
# 	dry shampoo i
# 	this shampoo it
# 	this shampoo work
# 	the shampoo and
# 	this shampoo and
# 	this shampoo do
# 	good shampoo i
# 	the shampoo be
# 	this shampoo for
# conditioner
# 	the shampoo conditioner
# 	this conditioner be
# 	and conditioner i
# 	this conditioner i
# 	the conditioner be
# gel
# 	the gel be
# 	shower gel and
# 	shower gel be
# lotion
# 	this lotion i
# 	body lotion i
# 	this lotion it
# 	good lotion ever
# 	this lotion be
# 	the lotion be
# 	the lotion and
# cleanser
# 	this cleanser it
# 	this cleanser be
# 	the cleanser and
# 	this cleanser i

# %% [markdown]
# В данном случае JAC справился не очень хорошо, остальные примерно одинаково, но, кажется, что результаты PMI выглядят получше. Опять же можно наблюдать лучшие результаты на cream. Выделяет триграммы с назначением, отношением к продукту, но довольно много предлогов и прочих таких вещей. Еще выделяет вид продукта (например ночной крем).
